# %% [markdown]
# # Goal
#
# * Primer design for clade of interest

# %% [markdown]
# # Var

# %%
base_dir = '/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/'
clade = 'Butyricimonas'
taxid = 574697

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(LeyLabRMisc)

# %%
df.dims()
work_dir = file.path(base_dir, clade)
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Butyricimonas

# %% [markdown]
# # Genome download
#
# * Downloading genomes from NCBI

# %% [markdown]
# ```
# OUTDIR=/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/
# mkdir -p $OUTDIR
# ncbi-genome-download -p 12 -s genbank -F fasta --genera Butyricimonas -o $OUTDIR bacteria
# ```

# %% [markdown]
# # Genome quality
#
# * Filtering genomes by quality

# %%
D = file.path(base_dir, clade, 'genbank')
files = list_files(D, '.fna.gz')
samps = data.frame(Name = files %>% as.character %>% basename,
                   Fasta = files,
                   Domain = 'Bacteria',
                   Taxid = taxid) %>%
    mutate(Name = gsub('\\.fna\\.gz$', '', Name),
           Fasta = gsub('/+', '/', Fasta))
samps

# writing file
outfile = file.path(D, 'samples.txt')
write_table(samps, outfile)
# Out:
#    Name
# 1  GCA_000379665.1_ASM37966v1_genomic
# 2  GCA_000519105.1_ASM51910v1_genomic
# ⋮  ⋮
# 28 GCA_902364335.1_MGYG-HGUT-00203_genomic
# 29 GCA_902376195.1_MGYG-HGUT-01552_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/genbank/bacteria/GCA_000379665.1/GCA_000379665.1_ASM37966v1_genomic.fna.gz
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/genbank/bacteria/GCA_000519105.1/GCA_000519105.1_ASM51910v1_genomic.fna.gz
# ⋮  ⋮
# 28 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/genbank/bacteria/GCA_902364335.1/GCA_902364335.1_MGYG-HGUT-00203_genomic.fna.gz
# 29 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/genbank/bacteria/GCA_902376195.1/GCA_902376195.1_MGYG-HGUT-01552_genomic.fna.gz
#    Domain   Taxid
# 1  Bacteria 244127
# 2  Bacteria 244127
# ⋮  ⋮        ⋮
# 28 Bacteria 244127
# 29 Bacteria 244127
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Butyricimonas/genbank/samples.txt

# %% [markdown]
# ### LLG

# %% [markdown]
# #### Config

# %%
cat_file(file.path(work_dir, 'config_llg.yaml'))
# Out:
# # table with genome --> fasta_file information
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/genbank/samples.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# # batch processing of genomes for certain steps
# ## increase to better parallelize
# batches: 2
#
# # Domain of genomes ('Archaea' or 'Bacteria)
# ## Use "Skip" if provided as a "Domain" column in the genome table
# Domain: Skip
#
# # software parameters
# # Use "Skip" to skip any of these steps. If no params for rule, use ""
# # dRep MAGs are not further analyzed, but you can de-rep & then use the de-rep genome table as input.
# params:
#   ionice: -c 3
#   # assembly assessment
#   seqkit: ""
#   quast: Skip #""
#   multiqc_on_quast: ""
#   checkm: ""
#   # de-replication (requires checkm)
#   drep: -comp 90 -con 5 -sa 0.999
#   # taxonomy
#   sourmash:
#     compute: Skip #--scaled 10000 -k 31
#     gather: -k 31
#   gtdbtk:
#     classify_wf: --min_perc_aa 10
#   # genome pairwise ANI
#   fastani: Skip #--fragLen 3000 --minFraction 0.2 -k 16
#   dashing: Skip #-k 31 --full-tsv
#   comparem_aai: Skip #--evalue 0.001
#   # gene annotation
#   gene_call:
#     prokka: Skip #""
#     multiqc_on_prokka: ""
#     prodigal: Skip #""
#   eggnog_mapper: ""
#   eggnog_mapper_annot: ""
#   # rRNA (16S alignment & phylogeny)
#   barrnap: Skip #--lencutoff 0.8
#   vsearch_per_genome_drep: --id 0.95    # Skip to prevent drep of 16S copies within each genome
#   qiime2_fasttree: ""
#   qiime2_iqtree: --p-alrt 1000 --p-abayes --p-lbp 1000  --p-substitution-model 'GTR+I+G'
#   # genome phylogeny
#   phylophlan_config: Skip #--map_dna diamond --db_aa diamond --map_aa diamond --msa mafft --trim trimal --tree1 fasttree --tree2 raxml
#   phylophlan: --diversity high --min_num_markers 50 --accurate
#   # phenotype
#   traitar: Skip #""
#   # biosynthetic gene clusters (BGCs)
#   antismash: Skip #--cb-knownclusters --cb-subclusters --asf
#   DeepBGC: Skip #--score 0.5 --classifier-score 0.5 --prodigal-meta-mode
#   # antimicrobial resistance (AMR)
#   abricate: Skip #--minid 75 --mincov 80
#   # CRISPRs
#   cctyper: Skip #--prodigal meta
#
# # databases
# databases:
#   checkM_data: /ebio/abt3_projects/databases_no-backup/checkM/
#   sourmash: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.sbt.json
#   sourmash_lca: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.lca.json.gz
#   gtdbtk: /ebio/abt3_projects/databases_no-backup/GTDB/release95/gtdbtk/db_info.md
#   phylophlan: /ebio/abt3_projects/databases_no-backup/phylophlan/PhyloPhlan/phylophlan.faa.bz2
#   eggnog: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog.db
#   eggnog_diamond: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog_proteins.dmnd
#   antismash: /ebio/abt3_projects/databases_no-backup/antismash/v5/
#   deepbgc: /ebio/abt3_projects/databases_no-backup/DeepBGC/
#   traitar: /ebio/abt3_projects/databases_no-backup/pfam/traitar/
#   abricate:
#     ncbi: /ebio/abt3_projects/databases_no-backup/abricate/ncbi/sequences
#     card: /ebio/abt3_projects/databases_no-backup/abricate/card/sequences
#     resfinder: /ebio/abt3_projects/databases_no-backup/abricate/resfinder/sequences
#     argannot: /ebio/abt3_projects/databases_no-backup/abricate/argannot/sequences
#     bacmet2: /ebio/abt3_projects/databases_no-backup/abricate/bacmet2/sequences
#     vfdb: /ebio/abt3_projects/databases_no-backup/abricate/vfdb/sequences
#     megares: /ebio/abt3_projects/databases_no-backup/abricate/megares/sequences
#     plasmidfinder: /ebio/abt3_projects/databases_no-backup/abricate/plasmidfinder/sequences
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   use_shared_mem: True
#   name: LLG

# %% [markdown]
# #### Run
#
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llg
# $ screen -L -S llg ./snakemake_sge.sh /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/config_llg.yaml 20 -F
# ```

# %% [markdown]
# ### Samples table of high-quality genomes

# %%
# checkM summary
checkm = file.path(work_dir, 'LLG_output', 'checkM', 'checkm_qa_summary.tsv') %>%
    read.delim(sep='\t') 
checkm
# Out:
#    Bin.Id                                  Marker.lineage        X..genomes
# 1  GCA_000379665.1_ASM37966v1_genomic      k__Bacteria (UID2569) 434
# 2  GCA_001915615.1_ASM191561v1_genomic     k__Bacteria (UID2569) 434
# ⋮  ⋮                                       ⋮                     ⋮
# 28 GCA_900184685.1_PRJEB20857_genomic      k__Bacteria (UID2569) 434
# 29 GCA_902364335.1_MGYG-HGUT-00203_genomic k__Bacteria (UID2569) 434
#    X..markers X..marker.sets Completeness Contamination Strain.heterogeneity
# 1  278        186            100.00       0.00          0
# 2  278        186             88.69       0.27          0
# ⋮  ⋮          ⋮              ⋮            ⋮             ⋮
# 28 278        186            100.00       0             0
# 29 278        186             99.46       0             0
#    Genome.size..bp. X..ambiguous.bases ⋯ X0 X1  X2 X3 X4 X5.
# 1  4770838           131               ⋯  0 278 0  0  0  0
# 2  4167409          2477               ⋯ 44 233 1  0  0  0
# ⋮  ⋮                ⋮                  ⋱ ⋮  ⋮   ⋮  ⋮  ⋮  ⋮
# 28 5300003            0                ⋯ 0  278 0  0  0  0
# 29 4537596          250                ⋯ 1  277 0  0  0  0
#    assembly.Id
# 1  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Butyricimonas|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.1
# 2  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Butyricimonas|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.2
# ⋮  ⋮
# 28 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Butyricimonas|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.13
# 29 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Butyricimonas|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.14
#    assembler.Id              taxon.Id
# 1  markers_qa_summary.tsv.1  NA
# 2  markers_qa_summary.tsv.2  NA
# ⋮  ⋮                         ⋮
# 28 markers_qa_summary.tsv.13 NA
# 29 markers_qa_summary.tsv.14 NA
#    File
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.1
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.2
# ⋮  ⋮
# 28 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.13
# 29 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.14

# %%
# dRep summary
drep = file.path(work_dir, 'LLG_output', 'drep', 'checkm_markers_qa_summary.tsv') %>%
    read.delim(sep='\t') %>%
    mutate(Bin.Id = gsub('.+/', '', genome),
           Bin.Id = gsub('\\.fna$', '', Bin.Id))
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000379665.1_ASM37966v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_001915615.1_ASM191561v1_genomic.fna
# ⋮  ⋮
# 28 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900184685.1_PRJEB20857_genomic.fna
# 29 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902364335.1_MGYG-HGUT-00203_genomic.fna
#    completeness contamination Bin.Id
# 1  100.00       0.00          GCA_000379665.1_ASM37966v1_genomic
# 2   88.69       0.27          GCA_001915615.1_ASM191561v1_genomic
# ⋮  ⋮            ⋮             ⋮
# 28 100.00       0             GCA_900184685.1_PRJEB20857_genomic
# 29  99.46       0             GCA_902364335.1_MGYG-HGUT-00203_genomic

# %%
# de-replicated genomes
drep_gen = file.path(work_dir, 'LLG_output', 'drep', 'dereplicated_genomes.tsv') %>%
    read.delim(sep='\t')
drep_gen
# Out:
#    Name
# 1  GCA_003991565.1_ASM399156v1_genomic
# 2  GCA_900258545.1_PRJEB22910_genomic
# ⋮  ⋮
# 16 GCA_014287455.1_ASM1428745v1_genomic
# 17 GCA_900184685.1_PRJEB20857_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/drep/drep/dereplicated_genomes/GCA_003991565.1_ASM399156v1_genomic.fna
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/drep/drep/dereplicated_genomes/GCA_900258545.1_PRJEB22910_genomic.fna
# ⋮  ⋮
# 16 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/drep/drep/dereplicated_genomes/GCA_014287455.1_ASM1428745v1_genomic.fna
# 17 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/LLG_output/drep/drep/dereplicated_genomes/GCA_900184685.1_PRJEB20857_genomic.fna

# %%
# GTDBTk summary
tax = file.path(work_dir, 'LLG_output', 'gtdbtk', 'gtdbtk_bac_summary.tsv') %>%
    read.delim(, sep='\t') %>%
    separate(classification, 
             c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'),
             sep=';') %>%
    select(-note, -classification_method, -pplacer_taxonomy,
           -other_related_references.genome_id.species_name.radius.ANI.AF.)
tax
# Out:
#    user_genome                             Domain      Phylum
# 1  GCA_000379665.1_ASM37966v1_genomic      d__Bacteria p__Bacteroidota
# 2  GCA_001915615.1_ASM191561v1_genomic     d__Bacteria p__Bacteroidota
# ⋮  ⋮                                       ⋮           ⋮
# 28 GCA_900184685.1_PRJEB20857_genomic      d__Bacteria p__Bacteroidota
# 29 GCA_902364335.1_MGYG-HGUT-00203_genomic d__Bacteria p__Bacteroidota
#    Class          Order            Family            Genus
# 1  c__Bacteroidia o__Bacteroidales f__Marinifilaceae g__Butyricimonas
# 2  c__Bacteroidia o__Bacteroidales f__Marinifilaceae g__Butyricimonas
# ⋮  ⋮              ⋮                ⋮                 ⋮
# 28 c__Bacteroidia o__Bacteroidales f__Marinifilaceae g__Butyricimonas
# 29 c__Bacteroidia o__Bacteroidales f__Marinifilaceae g__Butyricimonas
#    Species                       fastani_reference fastani_reference_radius ⋯
# 1  s__Butyricimonas synergistica GCF_000379665.1   95                       ⋯
# 2  s__Butyricimonas faecihominis GCF_003851945.2   95                       ⋯
# ⋮  ⋮                             ⋮                 ⋮                        ⋱
# 28 s__Butyricimonas sp900184685  GCF_900184685.1   95                       ⋯
# 29 s__Butyricimonas virosa       GCF_000519105.1   95                       ⋯
#    fastani_af closest_placement_reference closest_placement_radius
# 1  1.00       GCF_000379665.1             95
# 2  0.78       GCF_003851945.2             95
# ⋮  ⋮          ⋮                           ⋮
# 28 1.00       GCF_900184685.1             95
# 29 0.85       GCF_000519105.1             95
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas synergistica
# 2  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas faecihominis
# ⋮  ⋮
# 28 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas sp900184685
# 29 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas virosa
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.00                1.00                 96.57       11
# 2   98.09                0.78                 84.37       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 28 100.00                1.00                 96.71       11
# 29  97.98                0.85                 96.79       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 28 N/A       N/A
# 29 N/A       N/A

# %%
# checking overlap
cat('-- drep --\n')
overlap(basename(as.character(drep_gen$Fasta)), 
        basename(as.character(drep$genome)))
cat('-- checkm --\n')
overlap(drep$Bin.Id, checkm$Bin.Id)
cat('-- gtdbtk --\n')
overlap(drep$Bin.Id, tax$user_genome)
# Out:
# -- drep --
# intersect(x,y): 17
# setdiff(x,y): 0
# setdiff(y,x): 12
# union(x,y): 29
# -- checkm --
# intersect(x,y): 29
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 29
# -- gtdbtk --
# intersect(x,y): 29
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 29

# %%
# joining based on Bin.Id
drep = drep %>%
    inner_join(checkm, c('Bin.Id')) %>%
    mutate(GEN = genome %>% as.character %>% basename) %>%
    inner_join(drep_gen %>% mutate(GEN = Fasta %>% as.character %>% basename),
               by=c('GEN')) %>%
    inner_join(tax, c('Bin.Id'='user_genome')) #%>%
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000379665.1_ASM37966v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_002320175.1_ASM232017v1_genomic.fna
# ⋮  ⋮
# 16 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_014287455.1_ASM1428745v1_genomic.fna
# 17 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900184685.1_PRJEB20857_genomic.fna
#    completeness contamination Bin.Id
# 1  100.00       0             GCA_000379665.1_ASM37966v1_genomic
# 2   98.39       0             GCA_002320175.1_ASM232017v1_genomic
# ⋮  ⋮            ⋮             ⋮
# 16 100          0             GCA_014287455.1_ASM1428745v1_genomic
# 17 100          0             GCA_900184685.1_PRJEB20857_genomic
#    Marker.lineage        X..genomes X..markers X..marker.sets Completeness
# 1  k__Bacteria (UID2569) 434        278        186            100.00
# 2  k__Bacteria (UID2569) 434        278        186             98.39
# ⋮  ⋮                     ⋮          ⋮          ⋮              ⋮
# 16 k__Bacteria (UID2569) 434        278        186            100
# 17 k__Bacteria (UID2569) 434        278        186            100
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0             ⋯ 1.00       GCF_000379665.1
# 2  0             ⋯ 0.87       GCF_000519105.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 16 0             ⋯ 0.81       GCF_900184685.1
# 17 0             ⋯ 1.00       GCF_900184685.1
#    closest_placement_radius
# 1  95
# 2  95
# ⋮  ⋮
# 16 95
# 17 95
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas synergistica
# 2  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas virosa
# ⋮  ⋮
# 16 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas sp900184685
# 17 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas sp900184685
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.00                1.00                 96.57       11
# 2   98.27                0.87                 94.37       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 16  97.68                0.81                 96.73       11
# 17 100.00                1.00                 96.71       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 16 N/A       N/A
# 17 N/A       N/A

# %%
# filtering by quality
hq_genomes = drep %>%
    filter(completeness >= 90,
           contamination < 5,
           Strain.heterogeneity < 50)
hq_genomes
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000379665.1_ASM37966v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_002320175.1_ASM232017v1_genomic.fna
# ⋮  ⋮
# 16 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_014287455.1_ASM1428745v1_genomic.fna
# 17 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900184685.1_PRJEB20857_genomic.fna
#    completeness contamination Bin.Id
# 1  100.00       0             GCA_000379665.1_ASM37966v1_genomic
# 2   98.39       0             GCA_002320175.1_ASM232017v1_genomic
# ⋮  ⋮            ⋮             ⋮
# 16 100          0             GCA_014287455.1_ASM1428745v1_genomic
# 17 100          0             GCA_900184685.1_PRJEB20857_genomic
#    Marker.lineage        X..genomes X..markers X..marker.sets Completeness
# 1  k__Bacteria (UID2569) 434        278        186            100.00
# 2  k__Bacteria (UID2569) 434        278        186             98.39
# ⋮  ⋮                     ⋮          ⋮          ⋮              ⋮
# 16 k__Bacteria (UID2569) 434        278        186            100
# 17 k__Bacteria (UID2569) 434        278        186            100
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0             ⋯ 1.00       GCF_000379665.1
# 2  0             ⋯ 0.87       GCF_000519105.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 16 0             ⋯ 0.81       GCF_900184685.1
# 17 0             ⋯ 1.00       GCF_900184685.1
#    closest_placement_radius
# 1  95
# 2  95
# ⋮  ⋮
# 16 95
# 17 95
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas synergistica
# 2  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas virosa
# ⋮  ⋮
# 16 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas sp900184685
# 17 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Marinifilaceae;g__Butyricimonas;s__Butyricimonas sp900184685
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.00                1.00                 96.57       11
# 2   98.27                0.87                 94.37       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 16  97.68                0.81                 96.73       11
# 17 100.00                1.00                 96.71       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 16 N/A       N/A
# 17 N/A       N/A

# %%
# summarizing the taxonomy
df.dims(20)
hq_genomes %>%
    group_by(Family, Genus) %>%
    summarize(n_genomes = n(), .groups='drop')
df.dims()
# Out:
#   Family            Genus            n_genomes
# 1 f__Marinifilaceae g__Butyricimonas 17

# %%
# writing samples table for LLPRIMER
outfile = file.path(work_dir, 'samples_genomes_hq.txt')
hq_genomes %>%
    select(Bin.Id, Fasta) %>%
    rename('Taxon' = Bin.Id) %>%
    mutate(Taxon = gsub('_chromosome.+', '', Taxon),
           Taxon = gsub('_bin_.+', '', Taxon),
           Taxon = gsub('_genomic', '', Taxon),
           Taxon = gsub('_annotated_assembly', '', Taxon),
           Taxid = taxid) %>%
    write_table(outfile)
# Out:
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Butyricimonas/samples_genomes_hq.txt

# %% [markdown]
# # Primer design

# %% [markdown]
# ### Config

# %%
F = file.path(work_dir, 'primers', 'config.yaml')
cat_file(F)
# Out:
# #-- I/O --#
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/samples_genomes_hq.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/primers/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# #-- software parameters --#
# # See the README for a description
# params:
#   ionice: -c 3
#   cgp:
#     prodigal: ""
#     mmseqs:
#       method: cluster    # or linclust (faster)
#       run: --min-seq-id 0.8 -c 0.8
#     core_genes: --frac 1 --max-clusters 500
#     blastx: -evalue 1e-10 -max_target_seqs 3
#     blastx_nontarget: -evalue 1e-5 -max_target_seqs 30
#     align:
#       method: linsi
#       params: --auto --maxiterate 1000
#     primer3:
#       number: --num-primers 500
#       size: --opt-size 20 --min-size 18 --max-size 24
#       product: --opt-prod-size 150 --min-prod-size 100 --max-prod-size 200
#       Tm: --opt-tm 62 --min-tm 55 --max-tm 70 --max-tm-diff 1
#       PCR: --oligo-DNA 50 --salt-monovalent 50 --salt-divalent 1.5 --dNTPs 0.2
#       GC: --opt-gc 50 --min-gc 25 --max-gc 75
#       degeneracy: --max-degeneracy 128 --max-degeneracy-3prime 1 --window-3prime 5
#       internal_oligo: --make-oligo 0 --int-opt-size 20 --int-opt-tm 60
#     blastn: -max_target_seqs 500 -perc_identity 90
#     blast_filter: --perc-len 80 --min-amplicon-len 30 --max-amplicon-len 2000
#
# #-- database --#
# databases:
#   blast:
#     nucl: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nt
#     prot: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nr
#     gene_names: /ebio/abt3_projects/databases_no-backup/NCBI_nr_geneIDs/2021-01/nr_accession-geneNames.pkl
#   taxonomy:
#     names: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/names.dmp
#     nodes: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/nodes.dmp
#
# #-- snakemake pipeline --#
# pipeline:
#   snakemake_folder: ./
#   script_folder: bin/scripts/
#   name: LLPRIMER

# %% [markdown]
# ### Run

# %% [markdown]
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llprimer
# $ screen -L -S llprimer-But ./snakemake_sge.sh /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Butyricimonas/primers/config.yaml 50 -F
# ```

# %% [markdown]
# ### Summary

# %%
primer_info = read.delim(file.path(work_dir, 'primers', 'cgp', 'primers_final_info.tsv'), sep='\t')
primer_info %>% unique_n('primer sets', primer_set)
primer_info
# Out:
# No. of unique primer sets: 495
#      cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1    4          13         172                     172
# 2    4          13         172                     172
# ⋮    ⋮          ⋮          ⋮                       ⋮
# 4207 500        499        133                     133
# 4208 500        499        133                     133
#      amplicon_size_sd primer_id primer_type  sequence             length
# 1    0                13f       PRIMER_LEFT  GAAYCARGGACAYWGCCACC 20
# 2    0                13r       PRIMER_RIGHT MGCYTCDGCACCRCTATTCA 20
# ⋮    ⋮                ⋮         ⋮            ⋮                    ⋮
# 4207 0                499f      PRIMER_LEFT  ACBCCMTGYGCBGCAAAAAT 20
# 4208 0                499r      PRIMER_RIGHT GTTGRTCCCGGTGTTGCGTG 20
#      degeneracy ⋯ position_start position_end Tm_avg   Tm_sd    GC_avg
# 1    16         ⋯ 161            181          60.40519 1.951478 57.50000
# 2    24         ⋯ 313            333          61.39287 2.160181 54.16667
# ⋮    ⋮          ⋱ ⋮              ⋮            ⋮        ⋮        ⋮
# 4207 36         ⋯ 573            593          63.11378 2.487889 51.66667
# 4208  2         ⋯ 686            706          63.96520 1.143588 62.50000
#      GC_sd    hairpin_avg hairpin_sd homodimer_avg homodimer_sd
# 1    4.330127 10.70543    18.661427  -23.02055     15.93829
# 2    4.930066 42.22950     2.453775  -19.36984     24.02227
# ⋮    ⋮        ⋮           ⋮          ⋮             ⋮
# 4207 4.859127 31.85494    24.19495    6.798857     10.52647
# 4208 2.500000  0.00000     0.00000   -1.736426      0.00000

# %% [markdown]
# ### Gene cluster annotations

# %%
gene_annot = read.delim(file.path(work_dir, 'primers', 'cgp', 'core_clusters_blastx.tsv'), 
                        sep='\t') %>%
    mutate(cluster_id = gsub('cluster_', '', cluster_id) %>% as.Num) %>%
    semi_join(primer_info, c('cluster_id')) %>%
    mutate(gene_name = gsub(' \\[.+', '', subject_name),
           gene_taxonomy = gsub('.+\\[', '', subject_name),
           gene_taxonomy = gsub('\\]', '', gene_taxonomy))
gene_annot
# Out:
#     cluster_id query                            subject
# 1   4          4dd2fadf7df94a0babc664b2d3c2b220 NJC17858.1
# 2   4          4dd2fadf7df94a0babc664b2d3c2b220 MBB4027972.1
# ⋮   ⋮          ⋮                                ⋮
# 689 500        466e10a5838d4b9ebeea2eb8446771b8 WP_099293516.1
# 690 500        466e10a5838d4b9ebeea2eb8446771b8 WP_040371279.1
#     subject_name                                                  pident length
# 1   ornithine--oxo-acid transaminase [Butyricimonas paravirosa]   99.015 406
# 2   ornithine--oxo-acid transaminase [Butyricimonas faecihominis] 98.768 406
# ⋮   ⋮                                                             ⋮      ⋮
# 689 4Fe-4S binding protein [Butyricimonas sp. Marseille-P3923]    99.776 447
# 690 MULTISPECIES: 4Fe-4S binding protein [Butyricimonas]          95.302 447
#     mismatch qstart qend sstart send evalue slen qlen
# 1   4        1      1218 1      406  0      406  1221
# 2   5        1      1218 1      406  0      406  1221
# ⋮   ⋮        ⋮      ⋮    ⋮      ⋮    ⋮      ⋮    ⋮
# 689  1       1      1341 1      447  0      447  1344
# 690 21       1      1341 1      447  0      447  1344
#     sscinames
# 1   Butyricimonas paravirosa
# 2   Butyricimonas faecihominis
# ⋮   ⋮
# 689 Butyricimonas sp. Marseille-P3923
# 690 Butyricimonas synergistica;Butyricimonas;Butyricimonas synergistica DSM 23225;Butyricimonas sp. Marseille-P2440
#     staxids                       pident_rank
# 1   1472417                       1
# 2   1472416                       2
# ⋮   ⋮                             ⋮
# 689 1987504                       1
# 690 544644;574697;1121129;1816677 2
#     gene_name                            gene_taxonomy
# 1   ornithine--oxo-acid transaminase     Butyricimonas paravirosa
# 2   ornithine--oxo-acid transaminase     Butyricimonas faecihominis
# ⋮   ⋮                                    ⋮
# 689 4Fe-4S binding protein               Butyricimonas sp. Marseille-P3923
# 690 MULTISPECIES: 4Fe-4S binding protein Butyricimonas

# %%
df.dims(50)
gene_annot %>%
    distinct(cluster_id, gene_name) 
df.dims()
# Out:
#     cluster_id
# 1    4
# 2    7
# 3    9
# 4    9
# 5   13
# 6   14
# 7   14
# 8   14
# 9   16
# 10  16
# 11  18
# 12  18
# 13  22
# 14  22
# 15  24
# 16  24
# 17  25
# 18  25
# 19  26
# 20  26
# 21  33
# 22  33
# 23  35
# 24  35
# 25  37
# ⋮   ⋮
# 406 479
# 407 479
# 408 480
# 409 480
# 410 481
# 411 481
# 412 486
# 413 486
# 414 487
# 415 487
# 416 489
# 417 489
# 418 492
# 419 494
# 420 494
# 421 495
# 422 495
# 423 496
# 424 496
# 425 498
# 426 498
# 427 499
# 428 499
# 429 500
# 430 500
#     gene_name
# 1   ornithine--oxo-acid transaminase
# 2   MULTISPECIES: 50S ribosomal protein L27
# 3   MULTISPECIES: bifunctional methylenetetrahydrofolate dehydrogenase/methenyltetrahydrofolate cyclohydrolase FolD
# 4   bifunctional methylenetetrahydrofolate dehydrogenase/methenyltetrahydrofolate cyclohydrolase FolD
# 5   NADH:ubiquinone reductase (Na(+)-transporting) subunit E
# 6   MULTISPECIES: homocysteine biosynthesis protein
# 7   hypothetical protein BHV81_15115
# 8   homocysteine biosynthesis protein
# 9   MULTISPECIES: DNA polymerase III subunit delta
# 10  DNA polymerase III subunit delta
# 11  V-type ATP synthase subunit A
# 12  MULTISPECIES: V-type ATP synthase subunit A
# 13  MULTISPECIES: 30S ribosomal protein S20
# 14  30S ribosomal protein S20
# 15  MULTISPECIES: glycine cleavage system protein GcvH
# 16  glycine cleavage system protein GcvH
# 17  MULTISPECIES: ATP synthase F0 subunit C
# 18  ATP synthase F0 subunit C
# 19  MULTISPECIES: NADH-quinone oxidoreductase subunit L
# 20  NADH-quinone oxidoreductase subunit L
# 21  inorganic phosphate transporter
# 22  MULTISPECIES: inorganic phosphate transporter
# 23  MULTISPECIES: adenylosuccinate synthase
# 24  adenylosuccinate synthase
# 25  MULTISPECIES: lysophospholipid acyltransferase family protein
# ⋮   ⋮
# 406 MULTISPECIES: translation initiation factor IF-2
# 407 translation initiation factor IF-2
# 408 MULTISPECIES: phosphoribosylglycinamide formyltransferase
# 409 phosphoribosylglycinamide formyltransferase
# 410 magnesium transporter CorA family protein
# 411 MULTISPECIES: magnesium transporter CorA family protein
# 412 30S ribosomal protein S16
# 413 MULTISPECIES: 30S ribosomal protein S16
# 414 tryptophan--tRNA ligase
# 415 MULTISPECIES: tryptophan--tRNA ligase
# 416 MULTISPECIES: 30S ribosomal protein S10
# 417 30S ribosomal protein S10
# 418 phosphoribosylformylglycinamidine synthase
# 419 MULTISPECIES: cell division protein FtsZ
# 420 cell division protein FtsZ
# 421 MULTISPECIES: M23 family metallopeptidase
# 422 M23 family metallopeptidase
# 423 acyl-CoA carboxylase subunit beta
# 424 MULTISPECIES: acyl-CoA carboxylase subunit beta
# 425 MULTISPECIES: 50S ribosomal protein L17
# 426 50S ribosomal protein L17
# 427 DUF2149 domain-containing protein
# 428 MULTISPECIES: DUF2149 domain-containing protein
# 429 4Fe-4S binding protein
# 430 MULTISPECIES: 4Fe-4S binding protein

# %%
df.dims(50)
gene_annot %>%
    distinct(cluster_id, gene_taxonomy) 
df.dims()
# Out:
#     cluster_id gene_taxonomy
# 1    4         Butyricimonas paravirosa
# 2    4         Butyricimonas faecihominis
# 3    4         Butyricimonas virosa
# 4    7         Butyricimonas
# 5    7         unclassified Butyricimonas
# 6    9         Butyricimonas
# 7    9         Butyricimonas virosa
# 8   13         Butyricimonas paravirosa
# 9   13         Butyricimonas virosa
# 10  13         Odoribacter sp. AF15-53
# 11  14         Butyricimonas
# 12  14         Butyricimonas synergistica
# 13  14         Butyricimonas virosa
# 14  16         Butyricimonas
# 15  16         Butyricimonas virosa
# 16  16         Butyricimonas faecalis
# 17  18         Butyricimonas paravirosa
# 18  18         unclassified Butyricimonas
# 19  18         Butyricimonas faecihominis
# 20  22         Butyricimonas
# 21  22         unclassified Butyricimonas
# 22  22         Odoribacter sp. AF15-53
# 23  24         Butyricimonas
# 24  24         Butyricimonas sp. NSJ-56
# 25  24         Odoribacter sp. AF15-53
# ⋮   ⋮          ⋮
# 557 486        Butyricimonas synergistica
# 558 486        Butyricimonas
# 559 486        Odoribacter sp. AF15-53
# 560 487        Butyricimonas virosa
# 561 487        unclassified Butyricimonas
# 562 489        Odoribacteraceae
# 563 489        Odoribacter sp. AF15-53
# 564 489        Sanguibacteroides justesenii
# 565 492        Butyricimonas sp. Marseille-P3923
# 566 492        Butyricimonas sp. NSJ-56
# 567 492        Butyricimonas synergistica
# 568 494        Butyricimonas
# 569 494        Butyricimonas virosa
# 570 495        Butyricimonas
# 571 495        Butyricimonas virosa
# 572 496        Butyricimonas virosa
# 573 496        unclassified Butyricimonas
# 574 496        Butyricimonas paravirosa
# 575 498        Butyricimonas
# 576 498        Odoribacter sp. AF15-53
# 577 499        Butyricimonas virosa
# 578 499        Butyricimonas
# 579 500        Butyricimonas sp. NSJ-56
# 580 500        Butyricimonas sp. Marseille-P3923
# 581 500        Butyricimonas

# %% [markdown]
# ### Gene cluster: clostest related

# %%
gene_annot = read.delim(file.path(work_dir, 'primers', 'cgp', 'core_clusters_blastx_nontarget.tsv'), 
                        sep='\t') %>%
    mutate(cluster_id = gsub('cluster_', '', cluster_id) %>% as.Num) %>%
    semi_join(primer_info, c('cluster_id')) %>%
    mutate(gene_name = gsub(' \\[.+', '', subject_name),
           gene_taxonomy = gsub('.+\\[', '', subject_name),
           gene_taxonomy = gsub('\\]', '', gene_taxonomy))
gene_annot
# Out:
#      cluster_id query                            subject
# 1    4          4dd2fadf7df94a0babc664b2d3c2b220 RHR78904.1
# 2    4          4dd2fadf7df94a0babc664b2d3c2b220 RGG42580.1
# ⋮    ⋮          ⋮                                ⋮
# 6954 500        466e10a5838d4b9ebeea2eb8446771b8 OHD46869.1
# 6955 500        466e10a5838d4b9ebeea2eb8446771b8 MBI9053771.1
#      subject_name                                     pident length mismatch
# 1    None                                             98.276 406    7
# 2    None                                             99.007 403    4
# ⋮    ⋮                                                ⋮      ⋮      ⋮
# 6954 ferredoxin [Spirochaetes bacterium GWF1_31_7]    49.888 445    221
# 6955 4Fe-4S binding protein [Bacteroidales bacterium] 49.213 445    223
#      qstart qend sstart send evalue    slen qlen
# 1     1     1218 1      406  0         406  1221
# 2    10     1218 1      403  0         403  1221
# ⋮    ⋮      ⋮    ⋮      ⋮    ⋮         ⋮    ⋮
# 6954 10     1341 6      449  1.12e-167 461  1344
# 6955 10     1341 6      448  1.18e-167 450  1344
#      sscinames                                       staxids
# 1    Odoribacter sp. AF15-53                         2292236
# 2    Odoribacter sp. AM16-33;Odoribacter sp. AF21-41 2292048;2293111
# ⋮    ⋮                                               ⋮
# 6954 Spirochaetes bacterium GWF1_31_7                1802187
# 6955 Bacteroidales bacterium                         2030927
#      pident_rank gene_name              gene_taxonomy
# 1    2           None                   None
# 2    1           None                   None
# ⋮    ⋮           ⋮                      ⋮
# 6954 29          ferredoxin             Spirochaetes bacterium GWF1_31_7
# 6955 30          4Fe-4S binding protein Bacteroidales bacterium

# %%
df.dims(50)
gene_annot %>%
    filter(pident > 80,
           pident_rank <= 3) %>%
    select(cluster_id, gene_name, gene_taxonomy, pident)
    
df.dims()
# Out:
#     cluster_id
# 1    4
# 2    4
# 3    4
# 4    7
# 5    7
# 6    7
# 7    7
# 8    9
# 9    9
# 10   9
# 11  13
# 12  13
# 13  13
# 14  14
# 15  14
# 16  14
# 17  16
# 18  16
# 19  16
# 20  18
# 21  18
# 22  18
# 23  22
# 24  22
# 25  22
# ⋮   ⋮
# 623 486
# 624 487
# 625 487
# 626 487
# 627 489
# 628 489
# 629 489
# 630 492
# 631 492
# 632 492
# 633 494
# 634 495
# 635 496
# 636 496
# 637 496
# 638 498
# 639 498
# 640 498
# 641 498
# 642 499
# 643 499
# 644 499
# 645 500
# 646 500
# 647 500
#     gene_name
# 1   None
# 2   None
# 3   None
# 4   None
# 5   50S ribosomal protein L27
# 6   50S ribosomal protein L27
# 7   50S ribosomal protein L27
# 8   None
# 9   bifunctional methylenetetrahydrofolate dehydrogenase/methenyltetrahydrofolate cyclohydrolase FolD
# 10  bifunctional methylenetetrahydrofolate dehydrogenase/methenyltetrahydrofolate cyclohydrolase FolD
# 11  NADH:ubiquinone reductase (Na(+)-transporting) subunit E
# 12  NADH:ubiquinone reductase (Na(+)-transporting) subunit E
# 13  NADH:ubiquinone reductase (Na(+)-transporting) subunit E
# 14  homocysteine biosynthesis protein
# 15  homocysteine biosynthesis protein
# 16  hypothetical protein
# 17  DNA polymerase III subunit delta
# 18  DNA polymerase III subunit delta
# 19  DNA polymerase III subunit delta
# 20  V-type ATP synthase subunit A
# 21  V-type ATP synthase subunit A
# 22  V-type ATP synthase subunit A
# 23  30S ribosomal protein S20
# 24  None
# 25  30S ribosomal protein S20
# ⋮   ⋮
# 623 30S ribosomal protein S16
# 624 None
# 625 tryptophan--tRNA ligase
# 626 tryptophan--tRNA ligase
# 627 30S ribosomal protein S10
# 628 30S ribosomal protein S10
# 629 30S ribosomal protein S10
# 630 phosphoribosylformylglycinamidine synthase
# 631 None
# 632 phosphoribosylformylglycinamidine synthase
# 633 cell division protein FtsZ
# 634 M23 family metallopeptidase
# 635 None
# 636 acyl-CoA carboxylase subunit beta
# 637 acyl-CoA carboxylase subunit beta
# 638 None
# 639 50S ribosomal protein L17
# 640 50S ribosomal protein L17
# 641 50S ribosomal protein L17
# 642 None
# 643 DUF2149 domain-containing protein
# 644 DUF2149 domain-containing protein
# 645 4Fe-4S binding protein
# 646 None
# 647 4Fe-4S binding protein
#     gene_taxonomy                        pident
# 1   None                                 98.276
# 2   None                                 99.007
# 3   None                                 98.263
# 4   None                                 91.860
# 5   Odoribacter sp. AF15-53              89.535
# 6   Sanguibacteroides justesenii         84.884
# 7   bacterium                            84.884
# 8   None                                 97.938
# 9   Odoribacter sp. AF15-53              94.158
# 10  Sanguibacteroides justesenii         83.505
# 11  Odoribacter sp. AF15-53              99.029
# 12  Sanguibacteroides justesenii         95.631
# 13  Odoribacter splanchnicus             93.204
# 14  Odoribacter sp. AF15-53              97.090
# 15  Sanguibacteroides justesenii         88.684
# 16  Odoribacter sp. Z80                  86.364
# 17  Odoribacter sp. AF15-53              97.024
# 18  Sanguibacteroides justesenii         83.929
# 19  Sanguibacteroides justesenii         83.333
# 20  Odoribacter sp. AF21-41              99.658
# 21  Odoribacter sp. AF15-53              96.928
# 22  Sanguibacteroides justesenii         93.162
# 23  Odoribacter sp. AF15-53              91.566
# 24  None                                 91.566
# 25  Sanguibacteroides justesenii         90.361
# ⋮   ⋮                                    ⋮
# 623 Sanguibacteroides justesenii         85.714
# 624 None                                 99.083
# 625 Odoribacter sp. AF15-53              92.355
# 626 Sanguibacteroides justesenii         83.486
# 627 Odoribacter sp. AF15-53              99.010
# 628 Sanguibacteroides justesenii         99.010
# 629 Odoribacter sp. Z80                  98.020
# 630 Odoribacter sp. AF15-53              90.968
# 631 None                                 90.480
# 632 Sanguibacteroides justesenii         84.459
# 633 Odoribacter sp. AF15-53              93.246
# 634 Odoribacter sp. AF15-53              92.708
# 635 None                                 99.615
# 636 Sanguibacteroides justesenii         97.110
# 637 Sanguibacteroides justesenii         97.110
# 638 None                                 98.319
# 639 Sanguibacteroides justesenii         83.333
# 640 Bacteroidia bacterium                83.193
# 641 Sphingobacteriales bacterium TSM_CSS 83.193
# 642 None                                 99.065
# 643 Odoribacter sp. AF15-53              96.262
# 644 Lentimicrobiaceae bacterium          88.889
# 645 Odoribacter sp. AF15-53              87.946
# 646 None                                 86.771
# 647 Sanguibacteroides justesenii         80.269

# %% [markdown]
# # sessionInfo

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llg/')

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/')

# %%
sessionInfo()
