# %% [markdown]
# # Goal
#
# * Primer design for clade of interest

# %% [markdown]
# # Var

# %%
base_dir = '/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/'
clade = 'Anaerotruncus'
taxid = 244127

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(LeyLabRMisc)

# %%
df.dims()
work_dir = file.path(base_dir, clade)
make_dir(work_dir)
# Out:
# Directory already exists: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Anaerotruncus

# %% [markdown]
# # Genome download
#
# * Downloading genomes from NCBI

# %% [markdown]
# ```
# OUTDIR=/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/
# mkdir -p $OUTDIR
# ncbi-genome-download -p 12 -s genbank -F fasta --genera Anaerotruncus -o $OUTDIR bacteria
# ```

# %% [markdown]
# # Genome quality
#
# * Filtering genomes by quality

# %%
D = file.path(base_dir, clade, 'genbank')
files = list_files(D, '.fna.gz')
samps = data.frame(Name = files %>% as.character %>% basename,
                   Fasta = files,
                   Domain = 'Bacteria',
                   Taxid = taxid) %>%
    mutate(Name = gsub('\\.fna\\.gz$', '', Name),
           Fasta = gsub('/+', '/', Fasta))
samps

# writing file
outfile = file.path(D, 'samples.txt')
write_table(samps, outfile)
# Out:
#    Name
# 1  GCA_000154565.1_ASM15456v1_genomic
# 2  GCA_000403395.2_Anae_bact_G3_V1_genomic
# ⋮  ⋮
# 30 GCA_902363605.1_MGYG-HGUT-00131_genomic
# 31 GCA_904384175.1_Chicken_20_mag_154_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/genbank/bacteria/GCA_000154565.1/GCA_000154565.1_ASM15456v1_genomic.fna.gz
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/genbank/bacteria/GCA_000403395.2/GCA_000403395.2_Anae_bact_G3_V1_genomic.fna.gz
# ⋮  ⋮
# 30 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/genbank/bacteria/GCA_902363605.1/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna.gz
# 31 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/genbank/bacteria/GCA_904384175.1/GCA_904384175.1_Chicken_20_mag_154_genomic.fna.gz
#    Domain   Taxid
# 1  Bacteria 244127
# 2  Bacteria 244127
# ⋮  ⋮        ⋮
# 30 Bacteria 244127
# 31 Bacteria 244127
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Anaerotruncus/genbank/samples.txt

# %% [markdown]
# ### LLG

# %% [markdown]
# #### Config

# %%
cat_file(file.path(work_dir, 'config_llg.yaml'))
# Out:
# # table with genome --> fasta_file information
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/genbank/samples.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# # batch processing of genomes for certain steps
# ## increase to better parallelize
# batches: 2
#
# # Domain of genomes ('Archaea' or 'Bacteria)
# ## Use "Skip" if provided as a "Domain" column in the genome table
# Domain: Skip
#
# # software parameters
# # Use "Skip" to skip any of these steps. If no params for rule, use ""
# # dRep MAGs are not further analyzed, but you can de-rep & then use the de-rep genome table as input.
# params:
#   ionice: -c 3
#   # assembly assessment
#   seqkit: ""
#   quast: Skip #""
#   multiqc_on_quast: ""
#   checkm: ""
#   # de-replication (requires checkm)
#   drep: -comp 90 -con 5 -sa 0.999
#   # taxonomy
#   sourmash:
#     compute: Skip #--scaled 10000 -k 31
#     gather: -k 31
#   gtdbtk:
#     classify_wf: --min_perc_aa 10
#   # genome pairwise ANI
#   fastani: Skip #--fragLen 3000 --minFraction 0.2 -k 16
#   dashing: Skip #-k 31 --full-tsv
#   comparem_aai: Skip #--evalue 0.001
#   # gene annotation
#   gene_call:
#     prokka: Skip #""
#     multiqc_on_prokka: ""
#     prodigal: Skip #""
#   eggnog_mapper: ""
#   eggnog_mapper_annot: ""
#   # rRNA (16S alignment & phylogeny)
#   barrnap: Skip #--lencutoff 0.8
#   vsearch_per_genome_drep: --id 0.95    # Skip to prevent drep of 16S copies within each genome
#   qiime2_fasttree: ""
#   qiime2_iqtree: --p-alrt 1000 --p-abayes --p-lbp 1000  --p-substitution-model 'GTR+I+G'
#   # genome phylogeny
#   phylophlan_config: Skip #--map_dna diamond --db_aa diamond --map_aa diamond --msa mafft --trim trimal --tree1 fasttree --tree2 raxml
#   phylophlan: --diversity high --min_num_markers 50 --accurate
#   # phenotype
#   traitar: Skip #""
#   # biosynthetic gene clusters (BGCs)
#   antismash: Skip #--cb-knownclusters --cb-subclusters --asf
#   DeepBGC: Skip #--score 0.5 --classifier-score 0.5 --prodigal-meta-mode
#   # antimicrobial resistance (AMR)
#   abricate: Skip #--minid 75 --mincov 80
#   # CRISPRs
#   cctyper: Skip #--prodigal meta
#
# # databases
# databases:
#   checkM_data: /ebio/abt3_projects/databases_no-backup/checkM/
#   sourmash: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.sbt.json
#   sourmash_lca: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.lca.json.gz
#   gtdbtk: /ebio/abt3_projects/databases_no-backup/GTDB/release95/gtdbtk/db_info.md
#   phylophlan: /ebio/abt3_projects/databases_no-backup/phylophlan/PhyloPhlan/phylophlan.faa.bz2
#   eggnog: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog.db
#   eggnog_diamond: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog_proteins.dmnd
#   antismash: /ebio/abt3_projects/databases_no-backup/antismash/v5/
#   deepbgc: /ebio/abt3_projects/databases_no-backup/DeepBGC/
#   traitar: /ebio/abt3_projects/databases_no-backup/pfam/traitar/
#   abricate:
#     ncbi: /ebio/abt3_projects/databases_no-backup/abricate/ncbi/sequences
#     card: /ebio/abt3_projects/databases_no-backup/abricate/card/sequences
#     resfinder: /ebio/abt3_projects/databases_no-backup/abricate/resfinder/sequences
#     argannot: /ebio/abt3_projects/databases_no-backup/abricate/argannot/sequences
#     bacmet2: /ebio/abt3_projects/databases_no-backup/abricate/bacmet2/sequences
#     vfdb: /ebio/abt3_projects/databases_no-backup/abricate/vfdb/sequences
#     megares: /ebio/abt3_projects/databases_no-backup/abricate/megares/sequences
#     plasmidfinder: /ebio/abt3_projects/databases_no-backup/abricate/plasmidfinder/sequences
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   use_shared_mem: True
#   name: LLG

# %% [markdown]
# #### Run
#
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llg
# $ screen -L -S llg ./snakemake_sge.sh /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/config_llg.yaml 20 -F
# ```

# %% [markdown]
# ### Samples table of high-quality genomes

# %%
# checkM summary
checkm = file.path(work_dir, 'LLG_output', 'checkM', 'checkm_qa_summary.tsv') %>%
    read.delim(sep='\t') 
checkm
# Out:
#    Bin.Id                                  Marker.lineage
# 1  GCA_000154565.1_ASM15456v1_genomic      o__Clostridiales (UID1212)
# 2  GCA_000433975.1_MGS528_genomic          o__Clostridiales (UID1212)
# ⋮  ⋮                                       ⋮
# 30 GCA_900199635.1_PRJEB19460_genomic      o__Clostridiales (UID1212)
# 31 GCA_902363605.1_MGYG-HGUT-00131_genomic o__Clostridiales (UID1212)
#    X..genomes X..markers X..marker.sets Completeness Contamination
# 1  172        263        149            97.99        0.22
# 2  172        263        149            97.99        0.00
# ⋮  ⋮          ⋮          ⋮              ⋮            ⋮
# 30 172        263        149            99.33        0.00
# 31 172        263        149            97.99        1.34
#    Strain.heterogeneity Genome.size..bp. X..ambiguous.bases ⋯ X0 X1  X2 X3 X4
# 1  0                    3719688          800                ⋯ 3  259 1  0  0
# 2  0                    1881083          732                ⋯ 3  260 0  0  0
# ⋮  ⋮                    ⋮                ⋮                  ⋱ ⋮  ⋮   ⋮  ⋮  ⋮
# 30 0                    3145951           14                ⋯ 1  262 0  0  0
# 31 0                    3306065          265                ⋯ 3  257 3  0  0
#    X5.
# 1  0
# 2  0
# ⋮  ⋮
# 30 0
# 31 0
#    assembly.Id
# 1  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.1
# 2  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.2
# ⋮  ⋮
# 30 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.14
# 31 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.15
#    assembler.Id              taxon.Id
# 1  markers_qa_summary.tsv.1  NA
# 2  markers_qa_summary.tsv.2  NA
# ⋮  ⋮                         ⋮
# 30 markers_qa_summary.tsv.14 NA
# 31 markers_qa_summary.tsv.15 NA
#    File
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.1
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.2
# ⋮  ⋮
# 30 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.14
# 31 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.15

# %%
# dRep summary
drep = file.path(work_dir, 'LLG_output', 'drep', 'checkm_markers_qa_summary.tsv') %>%
    read.delim(sep='\t') %>%
    mutate(Bin.Id = gsub('.+/', '', genome),
           Bin.Id = gsub('\\.fna$', '', Bin.Id))
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 30 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 31 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 30 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 31 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic

# %%
# de-replicated genomes
drep_gen = file.path(work_dir, 'LLG_output', 'drep', 'dereplicated_genomes.tsv') %>%
    read.delim(sep='\t')
drep_gen
# Out:
#    Name
# 1  GCA_014284405.1_ASM1428440v1_genomic
# 2  GCA_900199635.1_PRJEB19460_genomic
# ⋮  ⋮
# 26 GCA_015554285.1_ASM1555428v1_genomic
# 27 GCA_000433975.1_MGS528_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/drep/drep/dereplicated_genomes/GCA_014284405.1_ASM1428440v1_genomic.fna
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/drep/drep/dereplicated_genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# ⋮  ⋮
# 26 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/drep/drep/dereplicated_genomes/GCA_015554285.1_ASM1555428v1_genomic.fna
# 27 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/drep/drep/dereplicated_genomes/GCA_000433975.1_MGS528_genomic.fna

# %%
# GTDBTk summary
tax = file.path(work_dir, 'LLG_output', 'gtdbtk', 'gtdbtk_bac_summary.tsv') %>%
    read.delim(, sep='\t') %>%
    separate(classification, 
             c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'),
             sep=';') %>%
    select(-note, -classification_method, -pplacer_taxonomy,
           -other_related_references.genome_id.species_name.radius.ANI.AF.)
tax
# Out:
#    user_genome                             Domain      Phylum
# 1  GCA_000154565.1_ASM15456v1_genomic      d__Bacteria p__Firmicutes_A
# 2  GCA_000433975.1_MGS528_genomic          d__Bacteria p__Firmicutes_A
# ⋮  ⋮                                       ⋮           ⋮
# 29 GCA_900199635.1_PRJEB19460_genomic      d__Bacteria p__Firmicutes_A
# 30 GCA_902363605.1_MGYG-HGUT-00131_genomic d__Bacteria p__Firmicutes_A
#    Class         Order              Family                Genus
# 1  c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
# 2  c__Clostridia o__Oscillospirales f__Acutalibacteraceae g__Eubacterium_R
# ⋮  ⋮             ⋮                  ⋮                     ⋮
# 29 c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
# 30 c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
#    Species                       fastani_reference fastani_reference_radius ⋯
# 1  s__Anaerotruncus colihominis  GCF_000154565.1   95.0                     ⋯
# 2  s__Eubacterium_R sp000433975  GCA_000433975.1   95.0                     ⋯
# ⋮  ⋮                             ⋮                 ⋮                        ⋱
# 29 s__Anaerotruncus massiliensis GCF_900199635.1   95.0                     ⋯
# 30 s__Anaerotruncus rubiinfantis GCF_900078395.1   95.0                     ⋯
#    fastani_af closest_placement_reference closest_placement_radius
# 1  1.0        GCF_000154565.1             95.0
# 2  1.0        GCA_000433975.1             95.0
# ⋮  ⋮          ⋮                           ⋮
# 29 1.0        GCF_900199635.1             95.0
# 30 0.91       GCF_900078395.1             95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 29 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 30 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 29 100.0                 1.0                  96.43       11
# 30 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 29 N/A       N/A
# 30 N/A       N/A

# %%
# checking overlap
cat('-- drep --\n')
overlap(basename(as.character(drep_gen$Fasta)), 
        basename(as.character(drep$genome)))
cat('-- checkm --\n')
overlap(drep$Bin.Id, checkm$Bin.Id)
cat('-- gtdbtk --\n')
overlap(drep$Bin.Id, tax$user_genome)
# Out:
# -- drep --
# intersect(x,y): 27
# setdiff(x,y): 0
# setdiff(y,x): 4
# union(x,y): 31
# -- checkm --
# intersect(x,y): 31
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 31
# -- gtdbtk --
# intersect(x,y): 30
# setdiff(x,y): 1
# setdiff(y,x): 0
# union(x,y): 31

# %%
# joining based on Bin.Id
drep = drep %>%
    inner_join(checkm, c('Bin.Id')) %>%
    mutate(GEN = genome %>% as.character %>% basename) %>%
    inner_join(drep_gen %>% mutate(GEN = Fasta %>% as.character %>% basename),
               by=c('GEN')) %>%
    inner_join(tax, c('Bin.Id'='user_genome')) #%>%
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 26 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 27 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 26 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 27 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic
#    Marker.lineage             X..genomes X..markers X..marker.sets Completeness
# 1  o__Clostridiales (UID1212) 172        263        149            97.99
# 2  o__Clostridiales (UID1212) 172        263        149            97.99
# ⋮  ⋮                          ⋮          ⋮          ⋮              ⋮
# 26 o__Clostridiales (UID1212) 172        263        149            99.33
# 27 o__Clostridiales (UID1212) 172        263        149            97.99
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0.22          ⋯ 1.0        GCF_000154565.1
# 2  0.00          ⋯ 1.0        GCA_000433975.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 26 0.00          ⋯ 1.0        GCF_900199635.1
# 27 1.34          ⋯ 0.91       GCF_900078395.1
#    closest_placement_radius
# 1  95.0
# 2  95.0
# ⋮  ⋮
# 26 95.0
# 27 95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 26 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 27 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 26 100.0                 1.0                  96.43       11
# 27 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 26 N/A       N/A
# 27 N/A       N/A

# %%
# filtering by quality
hq_genomes = drep %>%
    filter(completeness >= 90,
           contamination < 5,
           Strain.heterogeneity < 50,
           X..contigs < 300,
           Mean.contig.length..bp. > 10000)
hq_genomes
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 25 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 26 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 25 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 26 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic
#    Marker.lineage             X..genomes X..markers X..marker.sets Completeness
# 1  o__Clostridiales (UID1212) 172        263        149            97.99
# 2  o__Clostridiales (UID1212) 172        263        149            97.99
# ⋮  ⋮                          ⋮          ⋮          ⋮              ⋮
# 25 o__Clostridiales (UID1212) 172        263        149            99.33
# 26 o__Clostridiales (UID1212) 172        263        149            97.99
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0.22          ⋯ 1.0        GCF_000154565.1
# 2  0.00          ⋯ 1.0        GCA_000433975.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 25 0.00          ⋯ 1.0        GCF_900199635.1
# 26 1.34          ⋯ 0.91       GCF_900078395.1
#    closest_placement_radius
# 1  95.0
# 2  95.0
# ⋮  ⋮
# 25 95.0
# 26 95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 25 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 26 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 25 100.0                 1.0                  96.43       11
# 26 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 25 N/A       N/A
# 26 N/A       N/A

# %%
# summarizing the genome stats
hq_genomes %>% summary_x('completeness', completeness)
hq_genomes %>% summary_x('contamination', contamination)
hq_genomes %>% summary_x('No. of contigs', X..contigs)
hq_genomes %>% summary_x('N50', N50..contigs.)
hq_genomes %>% summary_x('Mean contig length', Mean.contig.length..bp.)
# Out:
#              Min.  1st Qu. Median Mean     3rd Qu. Max.  sd    sd_err_of_mean
# completeness 97.32 97.99   97.99  98.24538 98.66   99.33 0.683 0.279
#               Min. 1st Qu. Median Mean      3rd Qu. Max. sd    sd_err_of_mean
# contamination 0    0.055   0.22   0.4280769 0.59    1.34 0.495 0.202
#                Min. 1st Qu. Median Mean     3rd Qu. Max. sd     sd_err_of_mean
# No. of contigs 8    36      68     72.15385 96      251  85.307 34.826
#     Min.  1st Qu. Median   Mean     3rd Qu.  Max.    sd       sd_err_of_mean
# N50 48108 87859.5 112468.5 303948.2 248682.5 2375707 909825.5 371434.7
#                    Min.  1st Qu.  Median Mean    3rd Qu.  Max.   sd
# Mean contig length 14550 37144.25 45687  87416.5 101514.8 393242 140924.9
#                    sd_err_of_mean
# Mean contig length 57532.35

# %%
# summarizing the taxonomy
df.dims(20)
hq_genomes %>%
    group_by(Family, Genus) %>%
    summarize(n_genomes = n(), .groups='drop')
df.dims()
# Out:
#   Family                Genus            n_genomes
# 1 f__Acutalibacteraceae g__Eubacterium_R  1
# 2 f__Anaerovoracaceae   g__Emergencia     1
# 3 f__Ruminococcaceae    g__Anaerotruncus 24

# %%
# filtering by taxonomy
hq_genomes = hq_genomes %>%
    filter(Genus == 'g__Anaerotruncus')
hq_genomes
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_001404495.1_14207_7_62_genomic.fna
# ⋮  ⋮
# 23 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 24 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.36          GCA_001404495.1_14207_7_62_genomic
# ⋮  ⋮            ⋮             ⋮
# 23 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 24 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic
#    Marker.lineage             X..genomes X..markers X..marker.sets Completeness
# 1  o__Clostridiales (UID1212) 172        263        149            97.99
# 2  o__Clostridiales (UID1212) 172        263        149            97.99
# ⋮  ⋮                          ⋮          ⋮          ⋮              ⋮
# 23 o__Clostridiales (UID1212) 172        263        149            99.33
# 24 o__Clostridiales (UID1212) 172        263        149            97.99
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0.22          ⋯ 1.0        GCF_000154565.1
# 2  0.36          ⋯ 0.83       GCF_000154565.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 23 0.00          ⋯ 1.0        GCF_900199635.1
# 24 1.34          ⋯ 0.91       GCF_900078395.1
#    closest_placement_radius
# 1  95.0
# 2  95.0
# ⋮  ⋮
# 23 95.0
# 24 95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# ⋮  ⋮
# 23 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 24 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  99.07                 0.83                 95.50       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 23 100.0                 1.0                  96.43       11
# 24 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 23 N/A       N/A
# 24 N/A       N/A

# %%
# writing samples table for LLPRIMER
outfile = file.path(work_dir, 'samples_genomes_hq.txt')
hq_genomes %>%
    select(Bin.Id, Fasta) %>%
    rename('Taxon' = Bin.Id) %>%
    mutate(Taxon = gsub('_chromosome.+', '', Taxon),
           Taxon = gsub('_bin_.+', '', Taxon),
           Taxon = gsub('_genomic', '', Taxon),
           Taxon = gsub('_annotated_assembly', '', Taxon),
           Taxid = taxid) %>%
    write_table(outfile)
# Out:
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted//Anaerotruncus/samples_genomes_hq.txt

# %% [markdown]
# # Primer design

# %% [markdown]
# ### Config

# %%
F = file.path(work_dir, 'primers', 'config.yaml')
cat_file(F)
# Out:
# #-- I/O --#
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/samples_genomes_hq.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/primers/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# #-- software parameters --#
# # See the README for a description
# params:
#   ionice: -c 3
#   cgp:
#     prodigal: ""
#     mmseqs:
#       method: cluster    # or linclust (faster)
#       run: --min-seq-id 0.8 -c 0.8
#     core_genes: --frac 1 --max-clusters 500
#     blastx: -evalue 1e-10 -max_target_seqs 3
#     blastx_nontarget: -evalue 1e-5 -max_target_seqs 30
#     align:
#       method: linsi
#       params: --auto --maxiterate 1000
#     primer3:
#       number: --num-primers 500
#       size: --opt-size 20 --min-size 18 --max-size 24
#       product: --opt-prod-size 150 --min-prod-size 100 --max-prod-size 200
#       Tm: --opt-tm 62 --min-tm 55 --max-tm 70 --max-tm-diff 1
#       PCR: --oligo-DNA 50 --salt-monovalent 50 --salt-divalent 1.5 --dNTPs 0.2
#       GC: --opt-gc 50 --min-gc 25 --max-gc 75
#       degeneracy: --max-degeneracy 128 --max-degeneracy-3prime 1 --window-3prime 5
#       internal_oligo: --make-oligo 0 --int-opt-size 20 --int-opt-tm 60
#     blastn: -max_target_seqs 500 -perc_identity 90
#     blast_filter: --perc-len 80 --min-amplicon-len 30 --max-amplicon-len 2000
#
# #-- database --#
# databases:
#   blast:
#     nucl: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nt
#     prot: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nr
#     gene_names: /ebio/abt3_projects/databases_no-backup/NCBI_nr_geneIDs/2021-01/nr_accession-geneNames.pkl
#   taxonomy:
#     names: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/names.dmp
#     nodes: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/nodes.dmp
#
# #-- snakemake pipeline --#
# pipeline:
#   snakemake_folder: ./
#   script_folder: bin/scripts/
#   name: LLPRIMER

# %% [markdown]
# ### Run

# %% [markdown]
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llprimer
# $ screen -L -S llprimer-aner ./snakemake_sge.sh experiments/HMP_most-wanted/Anaerotruncus/primers/config.yaml 50 --notemp -F
# ```

# %% [markdown]
# ### Summary

# %%
primer_info = read.delim(file.path(work_dir, 'primers', 'cgp', 'primers_final_info.tsv'), sep='\t')
primer_info %>% unique_n('primer sets', primer_set)
primer_info
# Out:
# No. of unique primer sets: 276
#     cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1   4          267        121                     121
# 2   4          267        121                     121
# ⋮   ⋮          ⋮          ⋮                       ⋮
# 773 246        438        165                     165
# 774 246        438        165                     165
#     amplicon_size_sd primer_id primer_type  sequence              length
# 1   0                267f      PRIMER_LEFT  KMSAAGCTGCTSAARTCGGC  20
# 2   0                267r      PRIMER_RIGHT GGGGRCGRATVCGYTTCAT   19
# ⋮   ⋮                ⋮         ⋮            ⋮                     ⋮
# 773 0                438f      PRIMER_LEFT  YGAYTTYCCGCTBTCMAACTG 21
# 774 0                438r      PRIMER_RIGHT GAGSWYTTCTGRTAVGGCGG  20
#     degeneracy ⋯ position_start position_end Tm_avg   Tm_sd    GC_avg
# 1   32         ⋯ 141            161          62.20092 1.817715 57.50000
# 2   24         ⋯ 243            262          61.25268 2.574313 58.77193
# ⋮   ⋮          ⋱ ⋮              ⋮            ⋮        ⋮        ⋮
# 773 48         ⋯ 122            143          60.35574 1.733370 50.79365
# 774 48         ⋯ 267            287          60.29829 1.778744 58.33333
#     GC_sd    hairpin_avg hairpin_sd homodimer_avg homodimer_sd
# 1   4.330127 44.12935     7.786871  6.123101       9.199705
# 2   5.189544 53.52857    12.395231  7.186602      22.559500
# ⋮   ⋮        ⋮           ⋮          ⋮             ⋮
# 773 5.264484  4.452419   11.83836   -38.53541      5.906476
# 774 4.249183 13.355395   18.42953   -13.88619     23.840250

# %% [markdown]
# ### Gene cluster annotations

# %%
gene_annot = read.delim(file.path(work_dir, 'primers', 'cgp', 'core_clusters_blastx.tsv'), 
                        sep='\t') %>%
    mutate(cluster_id = gsub('cluster_', '', cluster_id) %>% as.Num) %>%
    semi_join(primer_info, c('cluster_id')) %>%
    mutate(gene_name = gsub(' \\[.+', '', subject_name),
           gene_taxonomy = gsub('.+\\[', '', subject_name),
           gene_taxonomy = gsub('\\]', '', gene_taxonomy))
gene_annot
# Out:
#     cluster_id query                            subject
# 1   4          abf8b17f07404c7183f7f0f8c044a48f WP_066455364.1
# 2   4          abf8b17f07404c7183f7f0f8c044a48f WP_147539073.1
# ⋮   ⋮          ⋮                                ⋮
# 227 246        ce2e4df7569647278c025e0d6334cd91 WP_006874432.1
# 228 246        ce2e4df7569647278c025e0d6334cd91 WP_195462589.1
#     subject_name                                                        pident
# 1   MULTISPECIES: 50S ribosomal protein L22 [Anaerotruncus]             100.000
# 2   50S ribosomal protein L22 [Anaerotruncus rubiinfantis]               99.099
# ⋮   ⋮                                                                   ⋮
# 227 glucose-1-phosphate adenylyltransferase [Anaerotruncus colihominis] 99.762
# 228 glucose-1-phosphate adenylyltransferase [Anaerotruncus colihominis] 99.048
#     length mismatch qstart qend sstart send evalue   slen qlen
# 1   111    0        1      333  1      111  3.92e-75 111  336
# 2   111    1        1      333  1      111  1.26e-74 111  336
# ⋮   ⋮      ⋮        ⋮      ⋮    ⋮      ⋮    ⋮        ⋮    ⋮
# 227 420    1        1      1260 1      420  0        420  1263
# 228 420    4        1      1260 1      420  0        420  1263
#     sscinames
# 1   Anaerotruncus;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27
# 2   Anaerotruncus rubiinfantis
# ⋮   ⋮
# 227 Anaerotruncus colihominis;Anaerotruncus colihominis DSM 17241
# 228 Anaerotruncus colihominis
#     staxids                pident_rank gene_name
# 1   244127;1720200;2292191 3           MULTISPECIES: 50S ribosomal protein L22
# 2   1720200                1           50S ribosomal protein L22
# ⋮   ⋮                      ⋮           ⋮
# 227 169435;445972          1           glucose-1-phosphate adenylyltransferase
# 228 169435                 2           glucose-1-phosphate adenylyltransferase
#     gene_taxonomy
# 1   Anaerotruncus
# 2   Anaerotruncus rubiinfantis
# ⋮   ⋮
# 227 Anaerotruncus colihominis
# 228 Anaerotruncus colihominis

# %%
df.dims(50)
gene_annot %>%
    distinct(cluster_id, gene_name) 
df.dims()
# Out:
#     cluster_id gene_name
# 1    4         MULTISPECIES: 50S ribosomal protein L22
# 2    4         50S ribosomal protein L22
# 3    5         MULTISPECIES: type I DNA topoisomerase
# 4    5         type I DNA topoisomerase
# 5   10         Catabolite repression HPr
# 6   10         HPr family phosphocarrier protein
# 7   10         MULTISPECIES: HPr family phosphocarrier protein
# 8   11         50S ribosomal protein L30
# 9   11         MULTISPECIES: 50S ribosomal protein L30
# 10  13         MULTISPECIES: 30S ribosomal protein S12
# 11  13         30S ribosomal protein S12
# 12  19         tRNA (guanosine(37)-N1)-methyltransferase TrmD
# 13  19         tRNA (guanine-N(1)-)-methyltransferase
# 14  20         MULTISPECIES: 30S ribosomal protein S3
# 15  20         30S ribosomal protein S3
# 16  22         MULTISPECIES: DNA-directed RNA polymerase subunit beta'
# 17  22         DNA-directed RNA polymerase subunit beta'
# 18  24         MULTISPECIES: glycosyltransferase family 2 protein
# 19  33         MULTISPECIES: 50S ribosomal protein L11
# 20  33         50S ribosomal protein L11
# 21  34         MULTISPECIES: 30S ribosomal protein S7
# 22  34         30S ribosomal protein S7
# 23  35         30S ribosomal protein S13
# 24  35         MULTISPECIES: 30S ribosomal protein S13
# 25  37         DNA-directed RNA polymerase subunit alpha
# ⋮   ⋮          ⋮
# 115 200        MULTISPECIES: UMP kinase
# 116 200        UMP kinase
# 117 201        NADH-quinone oxidoreductase subunit NuoF
# 118 204        preprotein translocase subunit SecA
# 119 206        MULTISPECIES: translation initiation factor IF-1
# 120 206        translation initiation factor IF-1
# 121 208        MULTISPECIES: uracil phosphoribosyltransferase
# 122 208        uracil phosphoribosyltransferase
# 123 214        chaperonin GroS
# 124 214        co-chaperone GroES
# 125 214        MULTISPECIES: co-chaperone GroES
# 126 220        phosphoenolpyruvate carboxykinase (GTP)
# 127 220        MULTISPECIES: phosphoenolpyruvate carboxykinase (GTP)
# 128 221        phenylacetate--CoA ligase
# 129 221        MULTISPECIES: phenylacetate--CoA ligase
# 130 227        MULTISPECIES: cell wall hydrolase
# 131 227        cell wall hydrolase
# 132 237        MULTISPECIES: 30S ribosomal protein S11
# 133 237        30S ribosomal protein S11
# 134 240        elongation factor G
# 135 241        MULTISPECIES: 50S ribosomal protein L19
# 136 241        50S ribosomal protein L19
# 137 243        MULTISPECIES: response regulator transcription factor
# 138 243        response regulator transcription factor
# 139 246        glucose-1-phosphate adenylyltransferase

# %%
df.dims(50)
gene_annot %>%
    distinct(cluster_id, gene_taxonomy) 
df.dims()
# Out:
#     cluster_id gene_taxonomy
# 1    4         Anaerotruncus
# 2    4         Anaerotruncus rubiinfantis
# 3    4         unclassified Anaerotruncus
# 4    5         Anaerotruncus
# 5    5         Anaerotruncus rubiinfantis
# 6    5         Anaerotruncus sp. G3(2012)
# 7   10         Anaerotruncus colihominis
# 8   10         Anaerotruncus
# 9   11         Anaerotruncus colihominis
# 10  11         unclassified Anaerotruncus
# 11  13         Anaerotruncus
# 12  13         Anaerotruncus colihominis
# 13  19         Anaerotruncus colihominis
# 14  19         Anaerotruncus colihominis DSM 17241
# 15  20         Anaerotruncus
# 16  20         Anaerotruncus colihominis
# 17  22         unclassified Anaerotruncus
# 18  22         Marasmitruncus massiliensis
# 19  22         Anaerotruncus colihominis
# 20  24         Anaerotruncus
# 21  24         unclassified Anaerotruncus
# 22  33         Anaerotruncus
# 23  33         Anaerotruncus colihominis
# 24  34         Anaerotruncus
# 25  34         Anaerotruncus rubiinfantis
# ⋮   ⋮          ⋮
# 142 206        Anaerotruncus
# 143 206        Marasmitruncus massiliensis
# 144 208        Anaerotruncus
# 145 208        Anaerotruncus rubiinfantis
# 146 208        Anaerotruncus sp. G3(2012)
# 147 214        Anaerotruncus colihominis DSM 17241
# 148 214        Anaerotruncus colihominis
# 149 214        unclassified Anaerotruncus
# 150 220        Anaerotruncus rubiinfantis
# 151 220        Anaerotruncus sp. AF02-27
# 152 220        Anaerotruncus
# 153 221        Anaerotruncus sp. G3(2012)
# 154 221        unclassified Anaerotruncus
# 155 221        Anaerotruncus
# 156 227        unclassified Anaerotruncus
# 157 227        Anaerotruncus
# 158 227        Anaerotruncus colihominis
# 159 237        Anaerotruncus
# 160 237        Candidatus Pararuminococcus gallinarum
# 161 240        Anaerotruncus colihominis
# 162 241        Anaerotruncus
# 163 241        Anaerotruncus colihominis
# 164 243        Anaerotruncus
# 165 243        Marasmitruncus massiliensis
# 166 246        Anaerotruncus colihominis

# %% [markdown]
# ### Gene cluster: closest related

# %%
gene_annot = read.delim(file.path(work_dir, 'primers', 'cgp', 'core_clusters_blastx_nontarget.tsv'), 
                        sep='\t') %>%
    mutate(cluster_id = gsub('cluster_', '', cluster_id) %>% as.Num) %>%
    semi_join(primer_info, c('cluster_id')) %>%
    mutate(gene_name = gsub(' \\[.+', '', subject_name),
           gene_taxonomy = gsub('.+\\[', '', subject_name),
           gene_taxonomy = gsub('\\]', '', gene_taxonomy))
gene_annot
# Out:
#      cluster_id query                            subject
# 1    4          abf8b17f07404c7183f7f0f8c044a48f WP_101908516.1
# 2    4          abf8b17f07404c7183f7f0f8c044a48f MBC8585943.1
# ⋮    ⋮          ⋮                                ⋮
# 2279 246        ce2e4df7569647278c025e0d6334cd91 WP_090266788.1
# 2280 246        ce2e4df7569647278c025e0d6334cd91 MBE6902255.1
#      subject_name
# 1    50S ribosomal protein L22 [Marasmitruncus massiliensis]
# 2    50S ribosomal protein L22 [Oscillospiraceae bacterium NSJ-64]
# ⋮    ⋮
# 2279 glucose-1-phosphate adenylyltransferase [Anaeromassilibacillus sp. Marseille-P4683]
# 2280 glucose-1-phosphate adenylyltransferase [Ruminococcaceae bacterium]
#      pident length mismatch qstart qend sstart send evalue   slen qlen
# 1    91.892 111     9       1      333  1      111  1.45e-70 111  336
# 2    90.090 111    11       1      333  1      111  1.60e-69 111  336
# ⋮    ⋮      ⋮      ⋮        ⋮      ⋮    ⋮      ⋮    ⋮        ⋮    ⋮
# 2279 73.580 405    107       1     1215 1      405  0        405  1263
# 2280 73.048 397    107      10     1200 5      401  0        401  1263
#      sscinames
# 1    Ruminococcaceae bacterium;Marasmitruncus massiliensis
# 2    Oscillospiraceae bacterium NSJ-64
# ⋮    ⋮
# 2279 Eubacteriaceae bacterium CHKCI005;Anaeromassilibacillus sp. Marseille-P4683
# 2280 Ruminococcaceae bacterium
#      staxids         pident_rank gene_name
# 1    1898205;1944642 1           50S ribosomal protein L22
# 2    2763678         2           50S ribosomal protein L22
# ⋮    ⋮               ⋮           ⋮
# 2279 1780381;2041843 28          glucose-1-phosphate adenylyltransferase
# 2280 1898205         30          glucose-1-phosphate adenylyltransferase
#      gene_taxonomy
# 1    Marasmitruncus massiliensis
# 2    Oscillospiraceae bacterium NSJ-64
# ⋮    ⋮
# 2279 Anaeromassilibacillus sp. Marseille-P4683
# 2280 Ruminococcaceae bacterium

# %%
df.dims(50)
gene_annot %>%
    filter(pident > 80,
           pident_rank <= 3) %>%
    select(cluster_id, gene_name, gene_taxonomy, pident)
    
df.dims()
# Out:
#     cluster_id gene_name
# 1    4         50S ribosomal protein L22
# 2    4         50S ribosomal protein L22
# 3    4         50S ribosomal protein L22
# 4    5         type I DNA topoisomerase
# 5    5         type I DNA topoisomerase
# 6    5         type I DNA topoisomerase
# 7   10         HPr family phosphocarrier protein
# 8   10         HPr family phosphocarrier protein
# 9   10         HPr family phosphocarrier protein
# 10  11         50S ribosomal protein L30
# 11  11         50S ribosomal protein L30
# 12  11         50S ribosomal protein L30
# 13  13         30S ribosomal protein S12
# 14  13         30S ribosomal protein S12
# 15  13         30S ribosomal protein S12
# 16  13         30S ribosomal protein S12
# 17  19         tRNA (guanosine(37)-N1)-methyltransferase TrmD
# 18  19         tRNA (guanosine(37)-N1)-methyltransferase TrmD
# 19  19         tRNA (guanosine(37)-N1)-methyltransferase TrmD
# 20  20         30S ribosomal protein S3
# 21  20         30S ribosomal protein S3
# 22  20         30S ribosomal protein S3
# 23  22         DNA-directed RNA polymerase subunit beta'
# 24  22         DNA-directed RNA polymerase subunit beta'
# 25  22         DNA-directed RNA polymerase subunit beta'
# ⋮   ⋮          ⋮
# 202 214        co-chaperonin GroES
# 203 214        co-chaperone GroES
# 204 220        phosphoenolpyruvate carboxykinase (GTP)
# 205 220        phosphoenolpyruvate carboxykinase (GTP)
# 206 220        phosphoenolpyruvate carboxykinase (GTP)
# 207 221        AMP-binding protein
# 208 221        phenylacetate--CoA ligase
# 209 221        phenylacetate--CoA ligase family protein
# 210 237        30S ribosomal protein S11
# 211 237        30S ribosomal protein S11
# 212 237        30S ribosomal protein S11
# 213 237        30S ribosomal protein S11
# 214 237        30S ribosomal protein S11
# 215 240        elongation factor G
# 216 240        elongation factor G
# 217 240        elongation factor G
# 218 241        50S ribosomal protein L19
# 219 241        50S ribosomal protein L19
# 220 241        50S ribosomal protein L19
# 221 243        response regulator transcription factor
# 222 243        response regulator transcription factor
# 223 243        DNA-binding response regulator
# 224 246        glucose-1-phosphate adenylyltransferase
# 225 246        glucose-1-phosphate adenylyltransferase
# 226 246        glucose-1-phosphate adenylyltransferase
#     gene_taxonomy                           pident
# 1   Marasmitruncus massiliensis             91.892
# 2   Oscillospiraceae bacterium NSJ-64       90.090
# 3   bacterium 1XD42-8                       89.189
# 4   Ruminococcaceae bacterium               84.173
# 5   Marasmitruncus massiliensis             84.029
# 6   Oscillospiraceae bacterium NSJ-64       81.727
# 7   Marasmitruncus massiliensis             97.701
# 8   bacterium 1XD42-8                       97.701
# 9   Hydrogenoanaerobacterium saccharovorans 95.402
# 10  Oscillospiraceae bacterium NSJ-64       88.136
# 11  Marasmitruncus massiliensis             88.136
# 12  Phocea massiliensis                     87.500
# 13  bacterium 1XD42-8                       97.656
# 14  Marasmitruncus massiliensis             96.094
# 15  Clostridiaceae bacterium NSJ-31         94.531
# 16  Angelakisella massiliensis              94.531
# 17  Ruminococcaceae bacterium               86.290
# 18  Marasmitruncus massiliensis             85.887
# 19  bacterium 1XD42-8                       80.328
# 20  Marasmitruncus massiliensis             90.667
# 21  Oscillospiraceae bacterium NSJ-64       84.681
# 22  Phocea massiliensis                     82.667
# 23  Marasmitruncus massiliensis             90.886
# 24  bacterium 1XD42-8                       89.228
# 25  Oscillospiraceae bacterium NSJ-64       89.076
# ⋮   ⋮                                       ⋮
# 202 uncultured Flavonifractor sp.           89.362
# 203 bacterium 1XD42-8                       89.362
# 204 Ruminococcaceae bacterium               87.544
# 205 bacterium 1XD42-8                       87.895
# 206 Marasmitruncus massiliensis             87.193
# 207 Marasmitruncus massiliensis             84.562
# 208 Ruminococcaceae bacterium               84.778
# 209 bacterium 1XD42-8                       82.679
# 210 Candidatus Pararuminococcus gallinarum  98.261
# 211 Ruminococcaceae bacterium               98.261
# 212 Clostridiaceae bacterium NSJ-31         98.261
# 213 bacterium 1XD42-8                       99.130
# 214 Angelakisella massiliensis              98.261
# 215 Ruminococcaceae bacterium               88.399
# 216 Marasmitruncus massiliensis             88.399
# 217 Oscillospiraceae bacterium NSJ-64       84.435
# 218 bacterium 1XD42-8                       91.228
# 219 Marasmitruncus massiliensis             89.474
# 220 Oscillospiraceae bacterium NSJ-64       82.456
# 221 Marasmitruncus massiliensis             94.348
# 222 Oscillospiraceae bacterium NSJ-64       90.435
# 223 bacterium 1XD42-8                       90.870
# 224 Oscillospiraceae bacterium NSJ-64       86.104
# 225 Marasmitruncus massiliensis             85.396
# 226 Ruminococcaceae bacterium               85.396

# %%
df.dims(50)
gene_annot %>%
    distinct(cluster_id, gene_name) 
df.dims()
# Out:
#     cluster_id
# 1    4
# 2    4
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# 8    5
# 9   10
# 10  10
# 11  10
# 12  10
# 13  11
# 14  11
# 15  11
# 16  13
# 17  13
# 18  13
# 19  19
# 20  19
# 21  20
# 22  20
# 23  20
# 24  22
# 25  22
# ⋮   ⋮
# 260 221
# 261 221
# 262 221
# 263 227
# 264 227
# 265 227
# 266 227
# 267 237
# 268 237
# 269 240
# 270 240
# 271 240
# 272 240
# 273 240
# 274 241
# 275 241
# 276 241
# 277 243
# 278 243
# 279 243
# 280 243
# 281 243
# 282 243
# 283 246
# 284 246
#     gene_name
# 1   50S ribosomal protein L22
# 2   MULTISPECIES: 50S ribosomal protein L22
# 3   type I DNA topoisomerase
# 4   MULTISPECIES: type I DNA topoisomerase
# 5   unnamed protein product
# 6   dNA topoisomerase
# 7   DNA topoisomerase-1
# 8   DNA topoisomerase 1
# 9   HPr family phosphocarrier protein
# 10  phosphocarrier, HPr family
# 11  phosphotransferase System HPr (HPr) Family
# 12  MULTISPECIES: HPr family phosphocarrier protein
# 13  50S ribosomal protein L30
# 14  ribosomal protein L30
# 15  MULTISPECIES: 50S ribosomal protein L30
# 16  30S ribosomal protein S12
# 17  ribosomal protein S12
# 18  MULTISPECIES: 30S ribosomal protein S12
# 19  tRNA (guanosine(37)-N1)-methyltransferase TrmD
# 20  tRNA (guanine-N(1)-)-methyltransferase
# 21  30S ribosomal protein S3
# 22  MULTISPECIES: 30S ribosomal protein S3
# 23  30S ribosomal protein S3, partial
# 24  DNA-directed RNA polymerase subunit beta'
# 25  MULTISPECIES: DNA-directed RNA polymerase subunit beta'
# ⋮   ⋮
# 260 MULTISPECIES: phenylacetate--CoA ligase
# 261 hypothetical protein EUBSIR_00342
# 262 phenylacetate-CoA ligase
# 263 cell wall hydrolase
# 264 cell Wall Hydrolase
# 265 MULTISPECIES: cell wall hydrolase
# 266 Cell wall hydrolase CwlJ
# 267 30S ribosomal protein S11
# 268 MULTISPECIES: 30S ribosomal protein S11
# 269 elongation factor G
# 270 MULTISPECIES: elongation factor G
# 271 putative translation elongation factor G
# 272 elongation factor G, partial
# 273 translation elongation factor 2 (EF-2/EF-G)
# 274 50S ribosomal protein L19
# 275 large subunit ribosomal protein L19
# 276 unnamed protein product
# 277 response regulator transcription factor
# 278 DNA-binding response regulator
# 279 response regulator
# 280 MULTISPECIES: response regulator transcription factor
# 281 response regulator receiver domain protein
# 282 DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain
# 283 glucose-1-phosphate adenylyltransferase
# 284 MULTISPECIES: glucose-1-phosphate adenylyltransferase

# %% [markdown]
# # sessionInfo

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llg/')
# Out:
# LLG
# ===
#
# Ley Lab Genome analysis pipeline (LLG)
#
# * Version: 0.1.9
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/gtdbtk.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::gtdbtk
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/checkm.yaml <==
# channels:
# - bioconda
# dependencies:
# - python=2.7
# - pigz
# - bioconda::prodigal
# - bioconda::pplacer
# - bioconda::checkm-genome
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/quast.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::seqkit
# - bioconda::quast>=5.0.0
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/sourmash.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::sourmash=2.0.0a4
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/fastqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::seqtk
# - bioconda::fastqc=0.11.7
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/multiqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::multiqc=1.4
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/hadley.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - conda-forge::r-ape
# - conda-forge::r-dplyr
# - conda-forge::r-tidyr
# - conda-forge::r-ggplot2
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/bbmap.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::bbmap=37.78
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/ani.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::dashing
# - bioconda::fastani
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/prokka.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::prokka
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/prodigal.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::prodigal
# - pip:
#   - biopython-convert
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/eggnog-mapper.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::eggnog-mapper
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/phylophlan.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::phylophlan
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/drep.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::mash
# - bioconda::checkm-genome
# - bioconda::drep
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/antismash.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - biopython=1.76
# - bioconda::antismash>=5.1.2
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/deepbgc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - conda-forge::biopython=1.76
# - bioconda::deepbgc=0.1.18
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/abricate.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::abricate
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/rRNA.yaml <==
# channels:
# - qiime2/label/r2020.2
# - conda-forge
# - bioconda
# - defaults
# dependencies:
# - barrnap
# - _libgcc_mutex=0.1
# - _openmp_mutex=4.5
# - _r-mutex=1.0.1
# - alsa-lib=1.1.5
# - arb-bio-tools=6.0.6
# - attrs=19.3.0
# - backcall=0.1.0
# - bibtexparser=1.1.0
# - binutils_impl_linux-64=2.33.1
# - binutils_linux-64=2.33.1
# - bioconductor-biobase=2.42.0
# - bioconductor-biocgenerics=0.28.0
# - bioconductor-biocparallel=1.16.6
# - bioconductor-biostrings=2.50.2
# - bioconductor-dada2=1.10.0
# - bioconductor-delayedarray=0.8.0
# - bioconductor-genomeinfodb=1.18.1
# - bioconductor-genomeinfodbdata=1.2.1
# - bioconductor-genomicalignments=1.18.1
# - bioconductor-genomicranges=1.34.0
# - bioconductor-iranges=2.16.0
# - bioconductor-rsamtools=1.34.0
# - bioconductor-s4vectors=0.20.1
# - bioconductor-shortread=1.40.0
# - bioconductor-summarizedexperiment=1.12.0
# - bioconductor-xvector=0.22.0
# - bioconductor-zlibbioc=1.28.0
# - biom-format=2.1.8
# - blas=2.14
# - blast=2.9.0
# - bleach=3.1.1
# - bokeh=1.4.0
# - boost=1.68.0
# - boost-cpp=1.68.0
# - bwidget=1.9.14
# - bzip2=1.0.8
# - ca-certificates=2019.11.28
# - cachecontrol=0.12.5
# - cairo=1.16.0
# - certifi=2019.11.28
# - cffi=1.13.2
# - chardet=3.0.4
# - click=7.0
# - cryptography=2.8
# - curl=7.68.0
# - cutadapt=2.8
# - cycler=0.10.0
# - cython=0.29.15
# - dbus=1.13.6
# - deblur=1.1.0
# - decorator=4.4.1
# - defusedxml=0.6.0
# - dendropy=4.4.0
# - dnaio=0.4.1
# - emperor=1.0.0
# - entrypoints=0.3
# - expat=2.2.9
# - fastcluster=1.1.26
# - fasttree=2.1.10
# - fontconfig=2.13.1
# - freetype=2.10.0
# - future=0.18.2
# - gcc_impl_linux-64=7.3.0
# - gcc_linux-64=7.3.0
# - gettext=0.19.8.1
# - gfortran_impl_linux-64=7.3.0
# - gfortran_linux-64=7.3.0
# - giflib=5.2.1
# - glib=2.58.3
# - gmp=6.2.0
# - gneiss=0.4.6
# - gnutls=3.6.5
# - graphite2=1.3.13
# - gsl=2.5
# - gst-plugins-base=1.14.5
# - gstreamer=1.14.5
# - gxx_impl_linux-64=7.3.0
# - gxx_linux-64=7.3.0
# - h5py=2.10.0
# - harfbuzz=2.4.0
# - hdf5=1.10.5
# - hdmedians=0.13
# - hmmer=3.1b2
# - icu=58.2
# - idna=2.9
# - ijson=2.6.1
# - importlib_metadata=1.5.0
# - ipykernel=5.1.4
# - ipython=7.12.0
# - ipython_genutils=0.2.0
# - ipywidgets=7.5.1
# - iqtree=1.6.12
# - jedi=0.16.0
# - jinja2=2.11.1
# - joblib=0.14.1
# - jpeg=9c
# - jsonschema=3.2.0
# - jupyter_client=6.0.0
# - jupyter_core=4.6.3
# - kiwisolver=1.1.0
# - krb5=1.16.4
# - lcms2=2.9
# - ld_impl_linux-64=2.33.1
# - libarbdb=6.0.6
# - libblas=3.8.0
# - libcblas=3.8.0
# - libcurl=7.68.0
# - libedit=3.1.20170329
# - libffi=3.2.1
# - libgcc=7.2.0
# - libgcc-ng=9.2.0
# - libgfortran-ng=7.3.0
# - libgomp=9.2.0
# - libiconv=1.15
# - liblapack=3.8.0
# - liblapacke=3.8.0
# - libopenblas=0.3.7
# - libpng=1.6.37
# - libsodium=1.0.17
# - libssh2=1.8.2
# - libstdcxx-ng=9.2.0
# - libtiff=4.1.0
# - libuuid=2.32.1
# - libxcb=1.13
# - libxml2=2.9.9
# - lockfile=0.12.2
# - lz4-c=1.8.3
# - mafft=7.310
# - make=4.3
# - markupsafe=1.1.1
# - matplotlib=3.1.1
# - matplotlib-base=3.1.1
# - mistune=0.8.4
# - more-itertools=8.2.0
# - msgpack-python=1.0.0
# - natsort=7.0.1
# - nbconvert=5.6.1
# - nbformat=5.0.4
# - ncurses=6.1
# - nettle=3.4.1
# - networkx=2.4
# - nose=1.3.7
# - notebook=6.0.3
# - numpy=1.18.1
# - olefile=0.46
# - openjdk=11.0.1
# - openssl=1.1.1d
# - packaging=20.1
# - pandas=0.25.3
# - pandoc=2.9.2
# - pandocfilters=1.4.2
# - pango=1.40.14
# - parso=0.6.1
# - patsy=0.5.1
# - pcre=8.44
# - perl=5.26.2
# - perl-archive-tar=2.32
# - perl-carp=1.38
# - perl-common-sense=3.74
# - perl-compress-raw-bzip2=2.087
# - perl-compress-raw-zlib=2.087
# - perl-exporter=5.72
# - perl-exporter-tiny=1.002001
# - perl-extutils-makemaker=7.36
# - perl-io-compress=2.087
# - perl-io-zlib=1.10
# - perl-json=4.02
# - perl-json-xs=2.34
# - perl-list-moreutils=0.428
# - perl-list-moreutils-xs=0.428
# - perl-pathtools=3.75
# - perl-scalar-list-utils=1.52
# - perl-types-serialiser=1.0
# - perl-xsloader=0.24
# - pexpect=4.8.0
# - pickleshare=0.7.5
# - pigz=2.3.4
# - pillow=7.0.0
# - pip=20.0.2
# - pixman=0.38.0
# - pluggy=0.12.0
# - prometheus_client=0.7.1
# - prompt_toolkit=3.0.3
# - psutil=5.7.0
# - pthread-stubs=0.4
# - ptyprocess=0.6.0
# - py=1.8.1
# - pycparser=2.19
# - pygments=2.5.2
# - pyopenssl=19.1.0
# - pyparsing=2.4.6
# - pyqt=5.9.2
# - pyrsistent=0.15.7
# - pysocks=1.7.1
# - pytest=5.3.5
# - python=3.6.7
# - python-dateutil=2.8.1
# - pytz=2019.3
# - pyyaml=5.3
# - pyzmq=19.0.0
# - q2-alignment=2020.2.0
# - q2-composition=2020.2.0
# - q2-cutadapt=2020.2.0
# - q2-dada2=2020.2.0
# - q2-deblur=2020.2.0
# - q2-demux=2020.2.0
# - q2-diversity=2020.2.0
# - q2-emperor=2020.2.0
# - q2-feature-classifier=2020.2.0
# - q2-feature-table=2020.2.0
# - q2-fragment-insertion=2020.2.0
# - q2-gneiss=2020.2.0
# - q2-longitudinal=2020.2.0
# - q2-metadata=2020.2.0
# - q2-phylogeny=2020.2.0
# - q2-quality-control=2020.2.0
# - q2-quality-filter=2020.2.0
# - q2-sample-classifier=2020.2.0
# - q2-taxa=2020.2.0
# - q2-types=2020.2.0
# - q2-vsearch=2020.2.0
# - q2cli=2020.2.0
# - q2templates=2020.2.0
# - qiime2=2020.2.0
# - qt=5.9.7
# - r-assertthat=0.2.1
# - r-backports=1.1.5
# - r-base=3.5.1
# - r-bh=1.72.0_3
# - r-bitops=1.0_6
# - r-cli=2.0.2
# - r-cluster=2.1.0
# - r-colorspace=1.4_1
# - r-crayon=1.3.4
# - r-data.table=1.12.6
# - r-digest=0.6.25
# - r-ellipsis=0.3.0
# - r-fansi=0.4.1
# - r-farver=2.0.3
# - r-formatr=1.7
# - r-futile.logger=1.4.3
# - r-futile.options=1.0.1
# - r-ggplot2=3.2.1
# - r-glue=1.3.1
# - r-gtable=0.3.0
# - r-hwriter=1.3.2
# - r-labeling=0.3
# - r-lambda.r=1.2.4
# - r-lattice=0.20_40
# - r-latticeextra=0.6_28
# - r-lazyeval=0.2.2
# - r-lifecycle=0.1.0
# - r-magrittr=1.5
# - r-mass=7.3_51.5
# - r-matrix=1.2_18
# - r-matrixstats=0.55.0
# - r-mgcv=1.8_31
# - r-munsell=0.5.0
# - r-nlme=3.1_144
# - r-permute=0.9_5
# - r-pillar=1.4.3
# - r-pkgconfig=2.0.3
# - r-plyr=1.8.5
# - r-r6=2.4.1
# - r-rcolorbrewer=1.1_2
# - r-rcpp=1.0.3
# - r-rcppparallel=4.4.4
# - r-rcurl=1.98_1.1
# - r-reshape2=1.4.3
# - r-rlang=0.4.4
# - r-scales=1.1.0
# - r-snow=0.4_3
# - r-stringi=1.4.3
# - r-stringr=1.4.0
# - r-tibble=2.1.3
# - r-utf8=1.1.4
# - r-vctrs=0.2.3
# - r-vegan=2.5_6
# - r-viridislite=0.3.0
# - r-withr=2.1.2
# - r-zeallot=0.1.0
# - raxml=8.2.12
# - readline=8.0
# - requests=2.23.0
# - scikit-bio=0.5.5
# - scikit-learn=0.22.1
# - scipy=1.4.1
# - seaborn=0.10.0
# - send2trash=1.5.0
# - sepp=4.3.10
# - setuptools=45.2.0
# - sina=1.6.0
# - sip=4.19.8
# - six=1.14.0
# - sortmerna=2.0
# - sqlite=3.30.1
# - statsmodels=0.11.1
# - tbb=2019.9
# - terminado=0.8.3
# - testpath=0.4.4
# - tk=8.6.10
# - tktable=2.10
# - tornado=6.0.3
# - traitlets=4.3.3
# - tzlocal=2.0.0
# - unifrac=0.10.0
# - urllib3=1.25.7
# - vsearch=2.7.0
# - wcwidth=0.1.8
# - webencodings=0.5.1
# - wheel=0.34.2
# - widgetsnbextension=3.5.1
# - xopen=0.8.4
# - xorg-fixesproto=5.0
# - xorg-inputproto=2.3.2
# - xorg-kbproto=1.0.7
# - xorg-libice=1.0.10
# - xorg-libsm=1.2.3
# - xorg-libx11=1.6.9
# - xorg-libxau=1.0.9
# - xorg-libxdmcp=1.1.3
# - xorg-libxext=1.3.4
# - xorg-libxfixes=5.0.3
# - xorg-libxi=1.7.10
# - xorg-libxrender=0.9.10
# - xorg-libxtst=1.2.3
# - xorg-recordproto=1.14.2
# - xorg-renderproto=0.11.1
# - xorg-xextproto=7.3.0
# - xorg-xproto=7.0.31
# - xz=5.2.4
# - yaml=0.2.2
# - zeromq=4.3.2
# - zipp=3.0.0
# - zlib=1.2.11
# - zstd=1.4.4
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/traitar.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - scipy
# - pandas
# - numpy
# - matplotlib
# - pigz
# - bioconda::hmmer
# - pip:
#   - traitar3>=0.1.1
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/cctyper.yaml <==
# channels:
# - conda-forge
# - bioconda
# - russel88
# dependencies:
# - pigz
# - cctyper
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/comparem.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::comparem

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/')
# Out:
# LLPRIMER
# ========
#
# Ley Lab Primer generation pipeline (LLPRIMER)
#
# * Version: 0.2.2
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/pdp.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - python=3.7
# - intervaltree
# - prodigal
# - blast
# - bedtools
# - mafft
# - mummer=3.23
# - emboss
# - primer3=1.1.4
# - biopython<1.78
# - pybedtools
# - joblib
# - tqdm
# - openpyxl
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/genes.yaml <==
# channels:
# - bioconda
# dependencies:
# - pigz
# - python=3
# - numpy
# - pyfaidx
# - bioconda::seqkit
# - bioconda::fasta-splitter
# - bioconda::vsearch
# - bioconda::prodigal
# - bioconda::mmseqs2
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/aln.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::kalign3
# - bioconda::mafft
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/blast.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::seqkit
# - bioconda::biopython<1.78
# - bioconda::blast>=2.10.1
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/taxids.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - intervaltree
# - taxonkit
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/primer3.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::biopython<1.78
# - bioconda::primer3-py

# %%
sessionInfo()
# Out:
# R version 3.6.3 (2020-02-29)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/tidyverse/lib/libopenblasp-r0.3.9.so
#
# locale:
#  [1] LC_CTYPE=C.UTF-8    LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ggplot2_3.3.1     tidyr_1.1.0       dplyr_1.0.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.4.6     magrittr_1.5     munsell_0.5.0    tidyselect_1.1.0
#  [5] uuid_0.1-4       colorspace_1.4-1 R6_2.4.1         rlang_0.4.6
#  [9] tools_3.6.3      grid_3.6.3       gtable_0.3.0     withr_2.2.0
# [13] htmltools_0.4.0  ellipsis_0.3.1   digest_0.6.25    tibble_3.0.1
# [17] lifecycle_0.2.0  crayon_1.3.4     IRdisplay_0.7.0  purrr_0.3.4
# [21] repr_1.1.0       base64enc_0.1-3  vctrs_0.3.1      IRkernel_1.1
# [25] glue_1.4.1       evaluate_0.14    stringi_1.4.6    pbdZMQ_0.3-3
# [29] compiler_3.6.3   pillar_1.4.4     scales_1.1.1     generics_0.0.2
# [33] jsonlite_1.6.1   pkgconfig_2.0.3
