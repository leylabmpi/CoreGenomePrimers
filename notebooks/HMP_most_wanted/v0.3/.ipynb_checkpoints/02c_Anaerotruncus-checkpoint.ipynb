# %% [markdown]
# # Goal
#
# * Primer design for clade of interest

# %% [markdown]
# # Var

# %%
base_dir = '/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/'
clade = 'Anaerotruncus'
domain = 'Bacteria'
taxid = 244127

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(LeyLabRMisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df.dims()
work_dir = file.path(base_dir, clade)
make_dir(work_dir)
# Out:
# Created directory: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3//Anaerotruncus

# %% [markdown]
# # Genome download
#
# * Downloading genomes from NCBI

# %% [markdown]
# ```
# OUTDIR=/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/
# mkdir -p $OUTDIR
# ncbi-genome-download -p 12 -s genbank -F fasta --genera Anaerotruncus -o $OUTDIR bacteria
# ```

# %% [markdown]
# # Genome quality
#
# * Filtering genomes by quality

# %%
D = file.path(base_dir, clade, 'genbank')
files = list_files(D, '.fna.gz')
samps = data.frame(Name = files %>% as.character %>% basename,
                   Fasta = files,
                   Domain = 'Bacteria',
                   Taxid = taxid) %>%
    mutate(Name = gsub('\\.fna\\.gz$', '', Name),
           Fasta = gsub('/+', '/', Fasta))
samps

# writing file
outfile = file.path(D, 'samples.txt')
write_table(samps, outfile)
# Out:
#    Name
# 1  GCA_000154565.1_ASM15456v1_genomic
# 2  GCA_000403395.2_Anae_bact_G3_V1_genomic
# ⋮  ⋮
# 30 GCA_902363605.1_MGYG-HGUT-00131_genomic
# 31 GCA_904384175.1_Chicken_20_mag_154_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/genbank/bacteria/GCA_000154565.1/GCA_000154565.1_ASM15456v1_genomic.fna.gz
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/genbank/bacteria/GCA_000403395.2/GCA_000403395.2_Anae_bact_G3_V1_genomic.fna.gz
# ⋮  ⋮
# 30 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/genbank/bacteria/GCA_902363605.1/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna.gz
# 31 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/genbank/bacteria/GCA_904384175.1/GCA_904384175.1_Chicken_20_mag_154_genomic.fna.gz
#    Domain   Taxid
# 1  Bacteria 244127
# 2  Bacteria 244127
# ⋮  ⋮        ⋮
# 30 Bacteria 244127
# 31 Bacteria 244127
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3//Anaerotruncus/genbank/samples.txt

# %% [markdown]
# ### LLG

# %% [markdown]
# #### Config

# %%
cat_file(file.path(work_dir, 'LLG', 'config.yaml'))
# Out:
# # table with genome --> fasta_file information
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/genbank/samples.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/LLG/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# # batch processing of genomes for certain steps
# ## increase to better parallelize
# batches: 2
#
# # Domain of genomes ('Archaea' or 'Bacteria)
# ## Use "Skip" if provided as a "Domain" column in the genome table
# Domain: Skip
#
# # software parameters
# # Use "Skip" to skip any of these steps. If no params for rule, use ""
# # dRep MAGs are not further analyzed, but you can de-rep & then use the de-rep genome table as input.
# params:
#   ionice: -c 3
#   # assembly assessment
#   seqkit: ""
#   quast: Skip #""
#   multiqc_on_quast: ""
#   checkm: ""
#   # de-replication (requires checkm)
#   drep: -comp 90 -con 5 -sa 0.999
#   # taxonomy
#   sourmash:
#     compute: Skip #--scaled 10000 -k 31
#     gather: -k 31
#   gtdbtk:
#     classify_wf: --min_perc_aa 10
#   # genome pairwise ANI
#   fastani: Skip #--fragLen 3000 --minFraction 0.2 -k 16
#   dashing: Skip #-k 31 --full-tsv
#   comparem_aai: Skip #--evalue 0.001
#   # gene annotation
#   gene_call:
#     prokka: Skip #""
#     multiqc_on_prokka: ""
#     prodigal: Skip #""
#   eggnog_mapper: ""
#   eggnog_mapper_annot: ""
#   # rRNA (16S alignment & phylogeny)
#   barrnap: Skip #--lencutoff 0.8
#   vsearch_per_genome_drep: --id 0.95    # Skip to prevent drep of 16S copies within each genome
#   qiime2_fasttree: ""
#   qiime2_iqtree: --p-alrt 1000 --p-abayes --p-lbp 1000  --p-substitution-model 'GTR+I+G'
#   # genome phylogeny
#   phylophlan_config: Skip #--map_dna diamond --db_aa diamond --map_aa diamond --msa mafft --trim trimal --tree1 fasttree --tree2 raxml
#   phylophlan: --diversity high --min_num_markers 50 --accurate
#   # phenotype
#   traitar: Skip #""
#   # biosynthetic gene clusters (BGCs)
#   antismash: Skip #--cb-knownclusters --cb-subclusters --asf
#   DeepBGC: Skip #--score 0.5 --classifier-score 0.5 --prodigal-meta-mode
#   # antimicrobial resistance (AMR)
#   abricate: Skip #--minid 75 --mincov 80
#   # CRISPRs
#   cctyper: Skip #--prodigal meta
#
# # databases
# databases:
#   checkM_data: /ebio/abt3_projects/databases_no-backup/checkM/
#   sourmash: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.sbt.json
#   sourmash_lca: /ebio/abt3_projects/databases_no-backup/sourmash/genbank-k31.lca.json.gz
#   gtdbtk: /ebio/abt3_projects/databases_no-backup/GTDB/release95/gtdbtk/db_info.md
#   phylophlan: /ebio/abt3_projects/databases_no-backup/phylophlan/PhyloPhlan/phylophlan.faa.bz2
#   eggnog: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog.db
#   eggnog_diamond: /ebio/abt3_projects/databases_no-backup/Eggnog/v2/eggnog_proteins.dmnd
#   antismash: /ebio/abt3_projects/databases_no-backup/antismash/v5/
#   deepbgc: /ebio/abt3_projects/databases_no-backup/DeepBGC/
#   traitar: /ebio/abt3_projects/databases_no-backup/pfam/traitar/
#   abricate:
#     ncbi: /ebio/abt3_projects/databases_no-backup/abricate/ncbi/sequences
#     card: /ebio/abt3_projects/databases_no-backup/abricate/card/sequences
#     resfinder: /ebio/abt3_projects/databases_no-backup/abricate/resfinder/sequences
#     argannot: /ebio/abt3_projects/databases_no-backup/abricate/argannot/sequences
#     bacmet2: /ebio/abt3_projects/databases_no-backup/abricate/bacmet2/sequences
#     vfdb: /ebio/abt3_projects/databases_no-backup/abricate/vfdb/sequences
#     megares: /ebio/abt3_projects/databases_no-backup/abricate/megares/sequences
#     plasmidfinder: /ebio/abt3_projects/databases_no-backup/abricate/plasmidfinder/sequences
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   use_shared_mem: True
#   name: LLG

# %% [markdown]
# #### Run
#
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llg
# $ screen -L -S llg ./snakemake_sge.sh /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/config_llg.yaml 20 -F
# ```

# %% [markdown]
# ### Samples table of high-quality genomes

# %%
# checkM summary
checkm = file.path(work_dir, 'LLG', 'checkM', 'checkm_qa_summary.tsv') %>%
    read.delim(sep='\t') 
checkm
# Out:
#    Bin.Id                                  Marker.lineage
# 1  GCA_000154565.1_ASM15456v1_genomic      o__Clostridiales (UID1212)
# 2  GCA_000433975.1_MGS528_genomic          o__Clostridiales (UID1212)
# ⋮  ⋮                                       ⋮
# 30 GCA_900199635.1_PRJEB19460_genomic      o__Clostridiales (UID1212)
# 31 GCA_902363605.1_MGYG-HGUT-00131_genomic o__Clostridiales (UID1212)
#    X..genomes X..markers X..marker.sets Completeness Contamination
# 1  172        263        149            97.99        0.22
# 2  172        263        149            97.99        0.00
# ⋮  ⋮          ⋮          ⋮              ⋮            ⋮
# 30 172        263        149            99.33        0.00
# 31 172        263        149            97.99        1.34
#    Strain.heterogeneity Genome.size..bp. X..ambiguous.bases ⋯ X0 X1  X2 X3 X4
# 1  0                    3719688          800                ⋯ 3  259 1  0  0
# 2  0                    1881083          732                ⋯ 3  260 0  0  0
# ⋮  ⋮                    ⋮                ⋮                  ⋱ ⋮  ⋮   ⋮  ⋮  ⋮
# 30 0                    3145951           14                ⋯ 1  262 0  0  0
# 31 0                    3306065          265                ⋯ 3  257 3  0  0
#    X5.
# 1  0
# 2  0
# ⋮  ⋮
# 30 0
# 31 0
#    assembly.Id
# 1  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.1
# 2  |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|1|checkm|markers_qa_summary.tsv.2
# ⋮  ⋮
# 30 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.14
# 31 |ebio|abt3_projects|software|dev|ll_pipelines|llprimer|experiments|HMP_most-wanted|Anaerotruncus|LLG_output|checkM|2|checkm|markers_qa_summary.tsv.15
#    assembler.Id              taxon.Id
# 1  markers_qa_summary.tsv.1  NA
# 2  markers_qa_summary.tsv.2  NA
# ⋮  ⋮                         ⋮
# 30 markers_qa_summary.tsv.14 NA
# 31 markers_qa_summary.tsv.15 NA
#    File
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.1
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/1/checkm/markers_qa_summary.tsv.2
# ⋮  ⋮
# 30 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.14
# 31 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/Anaerotruncus/LLG_output/checkM/2/checkm/markers_qa_summary.tsv.15

# %%
# dRep summary
drep = file.path(work_dir, 'LLG', 'drep', 'checkm_markers_qa_summary.tsv') %>%
    read.delim(sep='\t') %>%
    mutate(Bin.Id = gsub('.+/', '', genome),
           Bin.Id = gsub('\\.fna$', '', Bin.Id))
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 30 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 31 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 30 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 31 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic

# %%
# de-replicated genomes
drep_gen = file.path(work_dir, 'LLG', 'drep', 'dereplicated_genomes.tsv') %>%
    read.delim(sep='\t')
drep_gen
# Out:
#    Name
# 1  GCA_014284405.1_ASM1428440v1_genomic
# 2  GCA_900199635.1_PRJEB19460_genomic
# ⋮  ⋮
# 26 GCA_015554285.1_ASM1555428v1_genomic
# 27 GCA_000433975.1_MGS528_genomic
#    Fasta
# 1  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/LLG/drep/drep/dereplicated_genomes/GCA_014284405.1_ASM1428440v1_genomic.fna
# 2  /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/LLG/drep/drep/dereplicated_genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# ⋮  ⋮
# 26 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/LLG/drep/drep/dereplicated_genomes/GCA_015554285.1_ASM1555428v1_genomic.fna
# 27 /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/LLG/drep/drep/dereplicated_genomes/GCA_000433975.1_MGS528_genomic.fna

# %%
# GTDBTk summary
tax = file.path(work_dir, 'LLG', 'gtdbtk', 'gtdbtk_bac_summary.tsv') %>%
    read.delim(, sep='\t') %>%
    separate(classification, 
             c('Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species'),
             sep=';') %>%
    select(-note, -classification_method, -pplacer_taxonomy,
           -other_related_references.genome_id.species_name.radius.ANI.AF.)
tax
# Out:
#    user_genome                             Domain      Phylum
# 1  GCA_000154565.1_ASM15456v1_genomic      d__Bacteria p__Firmicutes_A
# 2  GCA_000433975.1_MGS528_genomic          d__Bacteria p__Firmicutes_A
# ⋮  ⋮                                       ⋮           ⋮
# 29 GCA_900199635.1_PRJEB19460_genomic      d__Bacteria p__Firmicutes_A
# 30 GCA_902363605.1_MGYG-HGUT-00131_genomic d__Bacteria p__Firmicutes_A
#    Class         Order              Family                Genus
# 1  c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
# 2  c__Clostridia o__Oscillospirales f__Acutalibacteraceae g__Eubacterium_R
# ⋮  ⋮             ⋮                  ⋮                     ⋮
# 29 c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
# 30 c__Clostridia o__Oscillospirales f__Ruminococcaceae    g__Anaerotruncus
#    Species                       fastani_reference fastani_reference_radius ⋯
# 1  s__Anaerotruncus colihominis  GCF_000154565.1   95.0                     ⋯
# 2  s__Eubacterium_R sp000433975  GCA_000433975.1   95.0                     ⋯
# ⋮  ⋮                             ⋮                 ⋮                        ⋱
# 29 s__Anaerotruncus massiliensis GCF_900199635.1   95.0                     ⋯
# 30 s__Anaerotruncus rubiinfantis GCF_900078395.1   95.0                     ⋯
#    fastani_af closest_placement_reference closest_placement_radius
# 1  1.0        GCF_000154565.1             95.0
# 2  1.0        GCA_000433975.1             95.0
# ⋮  ⋮          ⋮                           ⋮
# 29 1.0        GCF_900199635.1             95.0
# 30 0.91       GCF_900078395.1             95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 29 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 30 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 29 100.0                 1.0                  96.43       11
# 30 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 29 N/A       N/A
# 30 N/A       N/A

# %%
# checking overlap
cat('-- drep --\n')
overlap(basename(as.character(drep_gen$Fasta)), 
        basename(as.character(drep$genome)))
cat('-- checkm --\n')
overlap(drep$Bin.Id, checkm$Bin.Id)
cat('-- gtdbtk --\n')
overlap(drep$Bin.Id, tax$user_genome)
# Out:
# -- drep --
# intersect(x,y): 27
# setdiff(x,y): 0
# setdiff(y,x): 4
# union(x,y): 31
# -- checkm --
# intersect(x,y): 31
# setdiff(x,y): 0
# setdiff(y,x): 0
# union(x,y): 31
# -- gtdbtk --
# intersect(x,y): 30
# setdiff(x,y): 1
# setdiff(y,x): 0
# union(x,y): 31

# %%
# joining based on Bin.Id
drep = drep %>%
    inner_join(checkm, c('Bin.Id')) %>%
    mutate(GEN = genome %>% as.character %>% basename) %>%
    inner_join(drep_gen %>% mutate(GEN = Fasta %>% as.character %>% basename),
               by=c('GEN')) %>%
    inner_join(tax, c('Bin.Id'='user_genome')) #%>%
drep
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 26 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 27 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 26 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 27 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic
#    Marker.lineage             X..genomes X..markers X..marker.sets Completeness
# 1  o__Clostridiales (UID1212) 172        263        149            97.99
# 2  o__Clostridiales (UID1212) 172        263        149            97.99
# ⋮  ⋮                          ⋮          ⋮          ⋮              ⋮
# 26 o__Clostridiales (UID1212) 172        263        149            99.33
# 27 o__Clostridiales (UID1212) 172        263        149            97.99
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0.22          ⋯ 1.0        GCF_000154565.1
# 2  0.00          ⋯ 1.0        GCA_000433975.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 26 0.00          ⋯ 1.0        GCF_900199635.1
# 27 1.34          ⋯ 0.91       GCF_900078395.1
#    closest_placement_radius
# 1  95.0
# 2  95.0
# ⋮  ⋮
# 26 95.0
# 27 95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 26 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 27 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 26 100.0                 1.0                  96.43       11
# 27 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 26 N/A       N/A
# 27 N/A       N/A

# %%
# filtering by quality
hq_genomes = drep %>%
    filter(completeness >= 90,
           contamination < 5,
           Strain.heterogeneity < 50,
           X..contigs < 300,
           Mean.contig.length..bp. > 10000)
hq_genomes
# Out:
#    genome
# 1  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000154565.1_ASM15456v1_genomic.fna
# 2  /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_000433975.1_MGS528_genomic.fna
# ⋮  ⋮
# 25 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_900199635.1_PRJEB19460_genomic.fna
# 26 /ebio/abt3_scratch/nyoungblut/LLG_62325884640/genomes/GCA_902363605.1_MGYG-HGUT-00131_genomic.fna
#    completeness contamination Bin.Id
# 1  97.99        0.22          GCA_000154565.1_ASM15456v1_genomic
# 2  97.99        0.00          GCA_000433975.1_MGS528_genomic
# ⋮  ⋮            ⋮             ⋮
# 25 99.33        0.00          GCA_900199635.1_PRJEB19460_genomic
# 26 97.99        1.34          GCA_902363605.1_MGYG-HGUT-00131_genomic
#    Marker.lineage             X..genomes X..markers X..marker.sets Completeness
# 1  o__Clostridiales (UID1212) 172        263        149            97.99
# 2  o__Clostridiales (UID1212) 172        263        149            97.99
# ⋮  ⋮                          ⋮          ⋮          ⋮              ⋮
# 25 o__Clostridiales (UID1212) 172        263        149            99.33
# 26 o__Clostridiales (UID1212) 172        263        149            97.99
#    Contamination ⋯ fastani_af closest_placement_reference
# 1  0.22          ⋯ 1.0        GCF_000154565.1
# 2  0.00          ⋯ 1.0        GCA_000433975.1
# ⋮  ⋮             ⋱ ⋮          ⋮
# 25 0.00          ⋯ 1.0        GCF_900199635.1
# 26 1.34          ⋯ 0.91       GCF_900078395.1
#    closest_placement_radius
# 1  95.0
# 2  95.0
# ⋮  ⋮
# 25 95.0
# 26 95.0
#    closest_placement_taxonomy
# 1  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus colihominis
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Acutalibacteraceae;g__Eubacterium_R;s__Eubacterium_R sp000433975
# ⋮  ⋮
# 25 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus massiliensis
# 26 d__Bacteria;p__Firmicutes_A;c__Clostridia;o__Oscillospirales;f__Ruminococcaceae;g__Anaerotruncus;s__Anaerotruncus rubiinfantis
#    closest_placement_ani closest_placement_af msa_percent translation_table
# 1  100.0                 1.0                  97.18       11
# 2  100.0                 1.0                  96.57       11
# ⋮  ⋮                     ⋮                    ⋮           ⋮
# 25 100.0                 1.0                  96.43       11
# 26 99.26                 0.91                 96.35       11
#    red_value warnings
# 1  N/A       N/A
# 2  N/A       N/A
# ⋮  ⋮         ⋮
# 25 N/A       N/A
# 26 N/A       N/A

# %%
# summarizing the taxonomy
df.dims(20)
hq_genomes %>%
    group_by(Family, Genus) %>%
    summarize(n_genomes = n(), .groups='drop')
df.dims()
# Out:
#   Family                Genus            n_genomes
# 1 f__Acutalibacteraceae g__Eubacterium_R  1
# 2 f__Anaerovoracaceae   g__Emergencia     1
# 3 f__Ruminococcaceae    g__Anaerotruncus 24

# %%
# writing samples table for LLPRIMER
outfile = file.path(work_dir, 'samples_genomes_hq.txt')
hq_genomes %>%
    select(Bin.Id, Fasta) %>%
    rename('Taxon' = Bin.Id) %>%
    mutate(Taxon = gsub('_chromosome.+', '', Taxon),
           Taxon = gsub('_bin_.+', '', Taxon),
           Taxon = gsub('_genomic', '', Taxon),
           Taxon = gsub('_annotated_assembly', '', Taxon),
           Taxid = taxid,
           Domain = domain) %>%
    write_table(outfile)
# Out:
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3//Anaerotruncus/samples_genomes_hq.txt

# %% [markdown]
# # Primer design

# %% [markdown]
# ### Config

# %%
F = file.path(work_dir, 'primers', 'config.yaml')
cat_file(F)
# Out:
# #-- I/O --#
# samples_file: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/samples_genomes_hq.txt
#
# # output location
# output_dir: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/primers/
#
# # temporary file directory (your username will be added automatically)
# tmp_dir: /ebio/abt3_scratch/
#
# #-- software parameters --#
# # See the README for a description
# params:
#   ionice: -c 3
#   cgp:
#     prokka: ""
#     mmseqs:
#       method: cluster    # or linclust (faster)
#       run: --min-seq-id 0.8 -c 0.8
#     vsearch: --id 0.94
#     core_genes:
#       cds: --perc-genomes-cds 100 --copies-per-genome-cds 1 --max-clusters-cds 500
#       rRNA: --perc-genomes-rrna 100 --copies-per-genome-rrna 10 --max-clusters-rrna 500
#     align:
#       method: linsi
#       params: --auto --maxiterate 1000
#     primer3:
#       consensus: --consensus-threshold 0.34
#       number: --num-raw-primers 1000 --num-final-primers 10
#       size: --opt-size 20 --min-size 18 --max-size 26
#       product: --opt-prod-size 150 --min-prod-size 100 --max-prod-size 250
#       Tm: --opt-tm 62 --min-tm 54 --max-tm 70 --max-tm-diff 2.5
#       PCR: --oligo-DNA 50 --salt-monovalent 50 --salt-divalent 1.5 --dNTPs 0.2
#       GC: --opt-gc 50 --min-gc 25 --max-gc 75
#       degeneracy: --max-degeneracy 128 --max-degeneracy-3prime 6 --window-3prime 5
#       internal_oligo: --make-oligo 0 --int-opt-size 20 --int-opt-tm 60
#     blast_nontarget:
#       run_locally: False
#       cds: -evalue 1e-5 -max_target_seqs 30
#       rRNA: -evalue 1e-5 -max_target_seqs 30
#     blastn: -max_target_seqs 500 -perc_identity 90
#     blast_filter: --perc-len 80 --min-amplicon-len 30 --max-amplicon-len 2000
#     seqkit_amplicon: ""
#
# #-- database --#
# databases:
#   blast:
#     nucl: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nt
#     prot: /ebio/abt3_projects/databases_no-backup/NCBI_blastdb/nr
#     rRNA:
#       SSU: /ebio/abt3_projects/databases_no-backup/NCBI_rRNA/2021-01/SSU/16S_ribosomal_RNA
#       LSU: /ebio/abt3_projects/databases_no-backup/NCBI_rRNA/2021-01/LSU/LSU_prokaryote_rRNA
#     gene_names: /ebio/abt3_projects/databases_no-backup/NCBI_nr_geneIDs/2021-01/nr_accession-geneNames.pkl
#   taxonomy:
#     names: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/names.dmp
#     nodes: /ebio/abt3_projects/databases_no-backup/NCBI_taxonomy/2020-12-23/nodes.dmp
#
# #-- snakemake pipeline --#
# pipeline:
#   snakemake_folder: ./
#   script_folder: bin/scripts/
#   name: LLPRIMER

# %% [markdown]
# ### Run

# %% [markdown]
# ```
# (snakemake) @ rick:/ebio/abt3_projects/software/dev/ll_pipelines/llprimer
# $ screen -L -S llprimer-An ./snakemake_sge.sh /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3/Anaerotruncus/primers/config.yaml 30 --notemp
# ```

# %% [markdown]
# ## Summary

# %% [markdown]
# ### Primers

# %%
primer_info = read.delim(file.path(work_dir, 'primers', 'cgp', 'primers_final_info.tsv'), sep='\t')
primer_info %>% unique_n('primers', primer_set)
primer_info
# Out:
# No. of unique primers: 10
#    gene_type cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1  cds       2          73         109                     109
# 2  cds       2          73         109                     109
# ⋮  ⋮         ⋮          ⋮          ⋮                       ⋮
# 19 cds       2          925        107                     107
# 20 cds       2          925        107                     107
#    amplicon_size_sd primer_id primer_type  sequence               length ⋯
# 1  0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22     ⋯
# 2  0                73r       PRIMER_RIGHT CCYTGWCKCTGTTTRTGCTT   20     ⋯
# ⋮  ⋮                ⋮         ⋮            ⋮                      ⋮      ⋱
# 19 0                925f      PRIMER_LEFT  GAAAGTHAGASCTTCYGTDA   20     ⋯
# 20 0                925r      PRIMER_RIGHT CYTGWCKCTGTTTRTGCTT    19     ⋯
#    position_start position_end Tm_avg   Tm_sd    GC_avg   GC_sd    hairpin_avg
# 1   1              23          56.23671 1.915052 37.12121 3.787879 7.511429
# 2  90             110          57.99806 2.451058 47.50000 4.330127 0.000000
# ⋮  ⋮              ⋮            ⋮        ⋮        ⋮        ⋮        ⋮
# 19  2              22          53.48922 2.087977 40.83333 4.166667 7.511429
# 20 90             109          55.29904 2.585134 44.73684 4.558028 0.000000
#    hairpin_sd homodimer_avg homodimer_sd
# 1  16.79607   -27.56715     2.442498e+01
# 2   0.00000   -33.75316     1.421085e-14
# ⋮  ⋮          ⋮             ⋮
# 19 16.79607   -28.87287     2.245080e+01
# 20  0.00000   -33.75316     1.421085e-14

# %% [markdown]
# ### Gene clusters

# %%
# target gene info
gene_annot = read.delim(file.path(work_dir, 'primers', 'cgp', 'core_clusters_info.tsv'), 
                        sep='\t') %>%
    semi_join(primer_info, c('cluster_id')) 
gene_annot %>% distinct(gene_type, cluster_id) %>% nrow %>% cat('No. of clusters', ., '\n')
gene_annot
# Out:
# No. of clusters 1
#    gene_type cluster_id seq_uuid                         seq_orig_name
# 1  cds       2          95cf4c86c7cf4893b51f3ba76fc4d9e9 KHIIGKDO_03304
# 2  cds       2          663b3413e3c644b0bf9751a313c1cb7a AAEGJLIP_00392
# ⋮  ⋮         ⋮          ⋮                                ⋮
# 25 cds       2          5c515b50cccc4c8cb8d4d071d478865d HDMAFNJB_00208
# 26 cds       2          1f2a10cd3735420c99aa8058f1c4a798 LFEHCDIH_00979
#    contig_id         taxon                           start  end    score strand
# 1  DS544172.1        GCA_000154565.1_ASM15456v1       5547   5660  .     -
# 2  HF999344.1        GCA_000433975.1_MGS528          28097  28210  .     +
# ⋮  ⋮                 ⋮                               ⋮      ⋮      ⋮     ⋮
# 25 LT962687.1        GCA_900199635.1_PRJEB19460      100615 100728 .     +
# 26 CABJAH010000003.1 GCA_902363605.1_MGYG-HGUT-00131  74458  74571 .     +
#    annotation                cluster_name                     clust_id
# 1  50S ribosomal protein L36 492e52027403480f8ebe523409d9267f 2
# 2  50S ribosomal protein L36 492e52027403480f8ebe523409d9267f 2
# ⋮  ⋮                         ⋮                                ⋮
# 25 50S ribosomal protein L36 492e52027403480f8ebe523409d9267f 2
# 26 50S ribosomal protein L36 492e52027403480f8ebe523409d9267f 2

# %% [markdown]
# ### Gene cluster annotations

# %%
# non-target cds gene annotations
gene_nontarget = read.delim(file.path(work_dir, 'primers', 'cgp', 'nontarget', 'cds_blastx.tsv'), 
                        sep='\t') %>%
    semi_join(primer_info, c('cluster_id')) 
gene_nontarget
# Out:
#    cluster_id query                            subject
# 1  2          492e52027403480f8ebe523409d9267f WP_024729495.1
# 2  2          492e52027403480f8ebe523409d9267f MBC8570276.1
# ⋮  ⋮          ⋮                                ⋮
# 29 2          492e52027403480f8ebe523409d9267f EFB76111.1
# 30 2          492e52027403480f8ebe523409d9267f WP_073261210.1
#    subject_name                                                pident  length
# 1  MULTISPECIES: 50S ribosomal protein L36 [Ruminococcaceae]   100.000 37
# 2  None                                                         97.297 37
# ⋮  ⋮                                                           ⋮       ⋮
# 29 ribosomal protein L36 [Subdoligranulum variabile DSM 15176] 89.189  37
# 30 MULTISPECIES: 50S ribosomal protein L36 [Clostridiales]     91.892  37
#    mismatch qstart qend sstart send evalue   slen qlen
# 1  0        1      111  1      37   4.88e-16 37   114
# 2  1        1      111  1      37   7.32e-16 37   114
# ⋮  ⋮        ⋮      ⋮    ⋮      ⋮    ⋮        ⋮    ⋮
# 29 4        1      111  10     46   6.75e-15 46   114
# 30 3        1      111   1     37   6.89e-15 37   114
#    sscinames
# 1  Anaerotruncus colihominis;Oscillospiraceae;Anaerotruncus colihominis DSM 17241;Provencibacterium massiliense;Harryflintia acetispora;Oscillospiraceae bacterium;Clostridiales bacterium;bacterium 1XD42-1;bacterium 1XD42-8;Oscillospiraceae bacterium NSJ-64
# 2  Oscillospiraceae bacterium NSJ-54
# ⋮  ⋮
# 29 Subdoligranulum variabile DSM 15176
# 30 Clostridium sp. ATCC 29733;Eubacteriales;Bittarella massiliensis
#    staxids
# 1  169435;216572;445972;1841868;1849041;1898205;1898207;2320101;2320102;2763678
# 2  2763677
# ⋮  ⋮
# 29 411471
# 30 1507;186802;1720313
#    pident_rank
# 1  30
# 2   1
# ⋮  ⋮
# 29 28
# 30 20

# %% [markdown]
# ### Cluster taxonomic uniqueness

# %%
# closest seqID
gene_nontarget %>%
    filter(pident_rank == 1) %>%
    .$pident %>% summary_x('seq-ID to closest non-target')
# Out:
#                              Min.   1st Qu. Median Mean   3rd Qu. Max.   sd
# seq-ID to closest non-target 97.297 97.297  97.297 97.297 97.297  97.297 0
#                              sd_err_of_mean
# seq-ID to closest non-target 0

# %% [markdown]
# ### Primer quality

# %%
# summary
primer_info %>% unique_n('primer sets', primer_set)
primer_info %>% distinct(gene_type, cluster_id) %>% nrow %>% cat('No. of unique clusters:', ., '\n')
# Out:
# No. of unique primer sets: 10
# No. of unique clusters: 1

# %%
# primers per cluster
primer_info %>%
    distinct(cluster_id, primer_set) %>%
    group_by(cluster_id) %>%
    summarize(n_primer_sets = n(), .groups='drop') %>%
    .$n_primer_sets %>% summary_x('primer sets per cluster')
# Out:
#                         Min. 1st Qu. Median Mean 3rd Qu. Max. sd sd_err_of_mean
# primer sets per cluster 10   10      10     10   10      10   0  0

# %%
# primer quality
primer_info %>% filter(primer_type == 'PRIMER_LEFT') %>% .$amplicon_size_avg %>% summary_x('mean amplicon size')
primer_info %>% .$degeneracy %>% summary_x('degeneracy')
primer_info %>% .$degeneracy_3prime %>% summary_x('degeneracy (3-prime)')
# Out:
#                    Min. 1st Qu. Median Mean  3rd Qu. Max. sd    sd_err_of_mean
# mean amplicon size 103  107.25  109    108.1 109.75  110  2.588 1.057
#            Min. 1st Qu. Median Mean 3rd Qu. Max. sd     sd_err_of_mean
# degeneracy 12   16      20     24.4 36      36   10.121 4.132
#                      Min. 1st Qu. Median Mean 3rd Qu. Max. sd    sd_err_of_mean
# degeneracy (3-prime) 1    1       2      2.6  3       6    1.855 0.757

# %%
# adding non-target pident info
tmp1 = gene_nontarget %>%
    filter(pident_rank == 1) %>%
    distinct(cluster_id, pident, sscinames) %>%
    mutate(gene_type = 'cds')

primer_info_j = primer_info %>%
    inner_join(tmp1, c('gene_type', 'cluster_id'))
primer_info_j
# Out:
#     gene_type cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1   cds       2          73         109                     109
# 2   cds       2          73         109                     109
# ⋮   ⋮         ⋮          ⋮          ⋮                       ⋮
# 139 cds       2          925        107                     107
# 140 cds       2          925        107                     107
#     amplicon_size_sd primer_id primer_type  sequence               length ⋯
# 1   0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22     ⋯
# 2   0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22     ⋯
# ⋮   ⋮                ⋮         ⋮            ⋮                      ⋮      ⋱
# 139 0                925r      PRIMER_RIGHT CYTGWCKCTGTTTRTGCTT    19     ⋯
# 140 0                925r      PRIMER_RIGHT CYTGWCKCTGTTTRTGCTT    19     ⋯
#     Tm_avg   Tm_sd    GC_avg   GC_sd    hairpin_avg hairpin_sd homodimer_avg
# 1   56.23671 1.915052 37.12121 3.787879 7.511429    16.79607   -27.56715
# 2   56.23671 1.915052 37.12121 3.787879 7.511429    16.79607   -27.56715
# ⋮   ⋮        ⋮        ⋮        ⋮        ⋮           ⋮          ⋮
# 139 55.29904 2.585134 44.73684 4.558028 0           0          -33.75316
# 140 55.29904 2.585134 44.73684 4.558028 0           0          -33.75316
#     homodimer_sd pident
# 1   24.42498     97.297
# 2   24.42498     97.297
# ⋮   ⋮            ⋮
# 139 1.421085e-14 97.297
# 140 1.421085e-14 97.297
#     sscinames
# 1   Oscillospiraceae bacterium NSJ-54
# 2   Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# ⋮   ⋮
# 139 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 140 Acetanaerobacterium elongatum

# %%
# arrange by "best" primers
primer_info_jf = primer_info_j %>%
    group_by(primer_set) %>%
    mutate(max_degeneracy_3prime = max(degeneracy_3prime),  # max of [Fwd,Rev]
           max_degeneracy = max(degeneracy)) %>%
    ungroup() %>%
    arrange(pident, max_degeneracy_3prime, max_degeneracy) %>%
    head(n=30)

df.dims(30,40)
primer_info_jf
df.dims()
# Out:
#    gene_type cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1  cds       2          546        103                     103
# 2  cds       2          546        103                     103
# 3  cds       2          546        103                     103
# 4  cds       2          546        103                     103
# 5  cds       2          546        103                     103
# 6  cds       2          546        103                     103
# 7  cds       2          546        103                     103
# 8  cds       2          546        103                     103
# 9  cds       2          546        103                     103
# 10 cds       2          546        103                     103
# 11 cds       2          546        103                     103
# 12 cds       2          546        103                     103
# 13 cds       2          546        103                     103
# 14 cds       2          546        103                     103
# 15 cds       2          809        106                     106
# 16 cds       2          809        106                     106
# 17 cds       2          809        106                     106
# 18 cds       2          809        106                     106
# 19 cds       2          809        106                     106
# 20 cds       2          809        106                     106
# 21 cds       2          809        106                     106
# 22 cds       2          809        106                     106
# 23 cds       2          809        106                     106
# 24 cds       2          809        106                     106
# 25 cds       2          809        106                     106
# 26 cds       2          809        106                     106
# 27 cds       2          809        106                     106
# 28 cds       2          809        106                     106
# 29 cds       2           73        109                     109
# 30 cds       2           73        109                     109
#    amplicon_size_sd primer_id primer_type  sequence               length
# 1  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 2  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 3  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 4  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 5  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 6  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 7  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 8  0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 9  0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 10 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 11 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 12 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 13 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 14 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 15 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 16 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 17 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 18 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 19 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 20 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 21 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 22 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 23 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 24 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 25 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 26 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 27 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 28 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 29 0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22
# 30 0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22
#    degeneracy degeneracy_3prime position_start position_end Tm_avg   Tm_sd
# 1  12         2                  0              20          54.37386 1.763376
# 2  12         2                  0              20          54.37386 1.763376
# 3  12         2                  0              20          54.37386 1.763376
# 4  12         2                  0              20          54.37386 1.763376
# 5  12         2                  0              20          54.37386 1.763376
# 6  12         2                  0              20          54.37386 1.763376
# 7  12         2                  0              20          54.37386 1.763376
# 8  24         2                 83             103          56.37333 2.279991
# 9  24         2                 83             103          56.37333 2.279991
# 10 24         2                 83             103          56.37333 2.279991
# 11 24         2                 83             103          56.37333 2.279991
# 12 24         2                 83             103          56.37333 2.279991
# 13 24         2                 83             103          56.37333 2.279991
# 14 24         2                 83             103          56.37333 2.279991
# 15 12         2                  0              20          54.37386 1.763376
# 16 12         2                  0              20          54.37386 1.763376
# 17 12         2                  0              20          54.37386 1.763376
# 18 12         2                  0              20          54.37386 1.763376
# 19 12         2                  0              20          54.37386 1.763376
# 20 12         2                  0              20          54.37386 1.763376
# 21 12         2                  0              20          54.37386 1.763376
# 22 24         3                 87             106          56.74707 2.521808
# 23 24         3                 87             106          56.74707 2.521808
# 24 24         3                 87             106          56.74707 2.521808
# 25 24         3                 87             106          56.74707 2.521808
# 26 24         3                 87             106          56.74707 2.521808
# 27 24         3                 87             106          56.74707 2.521808
# 28 24         3                 87             106          56.74707 2.521808
# 29 36         3                  1              23          56.23671 1.915052
# 30 36         3                  1              23          56.23671 1.915052
#    GC_avg   GC_sd    hairpin_avg hairpin_sd homodimer_avg homodimer_sd pident
# 1  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 2  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 3  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 4  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 5  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 6  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 7  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 8  40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 9  40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 10 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 11 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 12 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 13 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 14 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 15 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 16 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 17 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 18 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 19 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 20 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 21 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 22 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 23 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 24 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 25 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 26 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 27 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 28 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 29 37.12121 3.787879 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 30 37.12121 3.787879 7.511429    16.79607   -27.56715     2.442498e+01 97.297
#    sscinames
# 1  Oscillospiraceae bacterium NSJ-54
# 2  Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 3  Oscillospiraceae bacterium
# 4  Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 5  Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 6  Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 7  Acetanaerobacterium elongatum
# 8  Oscillospiraceae bacterium NSJ-54
# 9  Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 10 Oscillospiraceae bacterium
# 11 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 12 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 13 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 14 Acetanaerobacterium elongatum
# 15 Oscillospiraceae bacterium NSJ-54
# 16 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 17 Oscillospiraceae bacterium
# 18 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 19 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 20 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 21 Acetanaerobacterium elongatum
# 22 Oscillospiraceae bacterium NSJ-54
# 23 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 24 Oscillospiraceae bacterium
# 25 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 26 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 27 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 28 Acetanaerobacterium elongatum
# 29 Oscillospiraceae bacterium NSJ-54
# 30 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
#    max_degeneracy_3prime max_degeneracy
# 1  2                     24
# 2  2                     24
# 3  2                     24
# 4  2                     24
# 5  2                     24
# 6  2                     24
# 7  2                     24
# 8  2                     24
# 9  2                     24
# 10 2                     24
# 11 2                     24
# 12 2                     24
# 13 2                     24
# 14 2                     24
# 15 3                     24
# 16 3                     24
# 17 3                     24
# 18 3                     24
# 19 3                     24
# 20 3                     24
# 21 3                     24
# 22 3                     24
# 23 3                     24
# 24 3                     24
# 25 3                     24
# 26 3                     24
# 27 3                     24
# 28 3                     24
# 29 3                     36
# 30 3                     36

# %% [markdown]
# #### w/ gene annotations

# %%
# joining
primer_info_jfj = primer_info_jf %>%
    left_join(gene_annot %>% distinct(gene_type, cluster_id, annotation),
              c('gene_type', 'cluster_id'))

df.dims(30,50)
primer_info_jfj
df.dims()
# Out:
#    gene_type cluster_id primer_set amplicon_size_consensus amplicon_size_avg
# 1  cds       2          546        103                     103
# 2  cds       2          546        103                     103
# 3  cds       2          546        103                     103
# 4  cds       2          546        103                     103
# 5  cds       2          546        103                     103
# 6  cds       2          546        103                     103
# 7  cds       2          546        103                     103
# 8  cds       2          546        103                     103
# 9  cds       2          546        103                     103
# 10 cds       2          546        103                     103
# 11 cds       2          546        103                     103
# 12 cds       2          546        103                     103
# 13 cds       2          546        103                     103
# 14 cds       2          546        103                     103
# 15 cds       2          809        106                     106
# 16 cds       2          809        106                     106
# 17 cds       2          809        106                     106
# 18 cds       2          809        106                     106
# 19 cds       2          809        106                     106
# 20 cds       2          809        106                     106
# 21 cds       2          809        106                     106
# 22 cds       2          809        106                     106
# 23 cds       2          809        106                     106
# 24 cds       2          809        106                     106
# 25 cds       2          809        106                     106
# 26 cds       2          809        106                     106
# 27 cds       2          809        106                     106
# 28 cds       2          809        106                     106
# 29 cds       2           73        109                     109
# 30 cds       2           73        109                     109
#    amplicon_size_sd primer_id primer_type  sequence               length
# 1  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 2  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 3  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 4  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 5  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 6  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 7  0                546f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 8  0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 9  0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 10 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 11 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 12 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 13 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 14 0                546r      PRIMER_RIGHT KCTGTTTRTGCTTBGGRTTT   20
# 15 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 16 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 17 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 18 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 19 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 20 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 21 0                809f      PRIMER_LEFT  ATGAAAGTHAGASCTTCYGT   20
# 22 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 23 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 24 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 25 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 26 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 27 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 28 0                809r      PRIMER_RIGHT GWCKCTGTTTRTGCTTBGG    19
# 29 0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22
# 30 0                73f       PRIMER_LEFT  TGAAAGTHAGASCTTCYGTDAA 22
#    degeneracy degeneracy_3prime position_start position_end Tm_avg   Tm_sd
# 1  12         2                  0              20          54.37386 1.763376
# 2  12         2                  0              20          54.37386 1.763376
# 3  12         2                  0              20          54.37386 1.763376
# 4  12         2                  0              20          54.37386 1.763376
# 5  12         2                  0              20          54.37386 1.763376
# 6  12         2                  0              20          54.37386 1.763376
# 7  12         2                  0              20          54.37386 1.763376
# 8  24         2                 83             103          56.37333 2.279991
# 9  24         2                 83             103          56.37333 2.279991
# 10 24         2                 83             103          56.37333 2.279991
# 11 24         2                 83             103          56.37333 2.279991
# 12 24         2                 83             103          56.37333 2.279991
# 13 24         2                 83             103          56.37333 2.279991
# 14 24         2                 83             103          56.37333 2.279991
# 15 12         2                  0              20          54.37386 1.763376
# 16 12         2                  0              20          54.37386 1.763376
# 17 12         2                  0              20          54.37386 1.763376
# 18 12         2                  0              20          54.37386 1.763376
# 19 12         2                  0              20          54.37386 1.763376
# 20 12         2                  0              20          54.37386 1.763376
# 21 12         2                  0              20          54.37386 1.763376
# 22 24         3                 87             106          56.74707 2.521808
# 23 24         3                 87             106          56.74707 2.521808
# 24 24         3                 87             106          56.74707 2.521808
# 25 24         3                 87             106          56.74707 2.521808
# 26 24         3                 87             106          56.74707 2.521808
# 27 24         3                 87             106          56.74707 2.521808
# 28 24         3                 87             106          56.74707 2.521808
# 29 36         3                  1              23          56.23671 1.915052
# 30 36         3                  1              23          56.23671 1.915052
#    GC_avg   GC_sd    hairpin_avg hairpin_sd homodimer_avg homodimer_sd pident
# 1  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 2  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 3  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 4  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 5  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 6  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 7  39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 8  40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 9  40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 10 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 11 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 12 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 13 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 14 40.83333 4.930066 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 15 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 16 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 17 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 18 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 19 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 20 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 21 39.16667 3.435921 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 22 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 23 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 24 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 25 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 26 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 27 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 28 50.87719 4.472824 0.000000     0.00000   -33.75316     2.131628e-14 97.297
# 29 37.12121 3.787879 7.511429    16.79607   -27.56715     2.442498e+01 97.297
# 30 37.12121 3.787879 7.511429    16.79607   -27.56715     2.442498e+01 97.297
#    sscinames
# 1  Oscillospiraceae bacterium NSJ-54
# 2  Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 3  Oscillospiraceae bacterium
# 4  Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 5  Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 6  Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 7  Acetanaerobacterium elongatum
# 8  Oscillospiraceae bacterium NSJ-54
# 9  Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 10 Oscillospiraceae bacterium
# 11 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 12 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 13 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 14 Acetanaerobacterium elongatum
# 15 Oscillospiraceae bacterium NSJ-54
# 16 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 17 Oscillospiraceae bacterium
# 18 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 19 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 20 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 21 Acetanaerobacterium elongatum
# 22 Oscillospiraceae bacterium NSJ-54
# 23 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
# 24 Oscillospiraceae bacterium
# 25 Clostridium sp. CAG:169;Clostridium sp. CAG:242;Negativibacillus massiliensis
# 26 Ruminococcus flavefaciens;Anaerofustis stercorihominis;Oscillospiraceae bacterium;Clostridiales bacterium
# 27 Eubacteriales;Candidatus Soleaferrea massiliensis AP7;Anaerotruncus massiliensis;Anaerotruncus rubiinfantis;Anaerotruncus sp. AF02-27;Anaerotruncus sp. 22A2-44;Oscillospiraceae bacterium;Clostridiaceae bacterium NSJ-31
# 28 Acetanaerobacterium elongatum
# 29 Oscillospiraceae bacterium NSJ-54
# 30 Oscillospiraceae;Hydrogenoanaerobacterium saccharovorans;Anaerotruncus sp. G3(2012);Oscillospiraceae bacterium;Marasmitruncus massiliensis;Anaerotruncus sp. X29;Anaerotruncus sp. 1XD22-93;Anaerotruncus sp. 1XD42-93
#    max_degeneracy_3prime max_degeneracy annotation
# 1  2                     24             50S ribosomal protein L36
# 2  2                     24             50S ribosomal protein L36
# 3  2                     24             50S ribosomal protein L36
# 4  2                     24             50S ribosomal protein L36
# 5  2                     24             50S ribosomal protein L36
# 6  2                     24             50S ribosomal protein L36
# 7  2                     24             50S ribosomal protein L36
# 8  2                     24             50S ribosomal protein L36
# 9  2                     24             50S ribosomal protein L36
# 10 2                     24             50S ribosomal protein L36
# 11 2                     24             50S ribosomal protein L36
# 12 2                     24             50S ribosomal protein L36
# 13 2                     24             50S ribosomal protein L36
# 14 2                     24             50S ribosomal protein L36
# 15 3                     24             50S ribosomal protein L36
# 16 3                     24             50S ribosomal protein L36
# 17 3                     24             50S ribosomal protein L36
# 18 3                     24             50S ribosomal protein L36
# 19 3                     24             50S ribosomal protein L36
# 20 3                     24             50S ribosomal protein L36
# 21 3                     24             50S ribosomal protein L36
# 22 3                     24             50S ribosomal protein L36
# 23 3                     24             50S ribosomal protein L36
# 24 3                     24             50S ribosomal protein L36
# 25 3                     24             50S ribosomal protein L36
# 26 3                     24             50S ribosomal protein L36
# 27 3                     24             50S ribosomal protein L36
# 28 3                     24             50S ribosomal protein L36
# 29 3                     36             50S ribosomal protein L36
# 30 3                     36             50S ribosomal protein L36

# %% [markdown]
# #### Writing table

# %%
F = file.path(work_dir, 'best_primers.tsv')
write_table(primer_info_jfj, F)
# Out:
# File written: /ebio/abt3_projects/software/dev/ll_pipelines/llprimer/experiments/HMP_most-wanted/v0.3//Anaerotruncus/best_primers.tsv

# %% [markdown]
# # sessionInfo

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llg/')
# Out:
# LLG
# ===
#
# Ley Lab Genome analysis pipeline (LLG)
#
# * Version: 0.2.4
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/gtdbtk.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - conda-forge::networkx
# - bioconda::gtdbtk
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/checkm.yaml <==
# channels:
# - bioconda
# dependencies:
# - python=2.7
# - pigz
# - bioconda::prodigal
# - bioconda::pplacer
# - bioconda::checkm-genome
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/quast.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::seqkit
# - bioconda::quast>=5.0.0
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/sourmash.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::sourmash=2.0.0a4
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/fastqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::seqtk
# - bioconda::fastqc=0.11.7
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/multiqc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::multiqc=1.4
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/hadley.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - conda-forge::r-ape
# - conda-forge::r-dplyr
# - conda-forge::r-tidyr
# - conda-forge::r-ggplot2
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/bbmap.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::bbmap=37.78
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/ani.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::dashing
# - bioconda::fastani
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/prokka.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::prokka
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/prodigal.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::prodigal
# - pip:
#   - biopython-convert
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/eggnog-mapper.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::eggnog-mapper
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/phylophlan.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::phylophlan
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/drep.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::mash
# - bioconda::checkm-genome
# - bioconda::fastani
# - bioconda::drep
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/antismash.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - biopython=1.77
# - bioconda::blast=2.9
# - bioconda::antismash>=5.1.2
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/deepbgc.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::deepbgc
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/abricate.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - bioconda::abricate
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/rRNA.yaml <==
# channels:
# - qiime2/label/r2020.2
# - conda-forge
# - bioconda
# - defaults
# dependencies:
# - barrnap
# - _libgcc_mutex=0.1
# - _openmp_mutex=4.5
# - _r-mutex=1.0.1
# - alsa-lib=1.1.5
# - arb-bio-tools=6.0.6
# - attrs=19.3.0
# - backcall=0.1.0
# - bibtexparser=1.1.0
# - binutils_impl_linux-64=2.33.1
# - binutils_linux-64=2.33.1
# - bioconductor-biobase=2.42.0
# - bioconductor-biocgenerics=0.28.0
# - bioconductor-biocparallel=1.16.6
# - bioconductor-biostrings=2.50.2
# - bioconductor-dada2=1.10.0
# - bioconductor-delayedarray=0.8.0
# - bioconductor-genomeinfodb=1.18.1
# - bioconductor-genomeinfodbdata=1.2.1
# - bioconductor-genomicalignments=1.18.1
# - bioconductor-genomicranges=1.34.0
# - bioconductor-iranges=2.16.0
# - bioconductor-rsamtools=1.34.0
# - bioconductor-s4vectors=0.20.1
# - bioconductor-shortread=1.40.0
# - bioconductor-summarizedexperiment=1.12.0
# - bioconductor-xvector=0.22.0
# - bioconductor-zlibbioc=1.28.0
# - biom-format=2.1.8
# - blas=2.14
# - blast=2.9.0
# - bleach=3.1.1
# - bokeh=1.4.0
# - boost=1.68.0
# - boost-cpp=1.68.0
# - bwidget=1.9.14
# - bzip2=1.0.8
# - ca-certificates=2019.11.28
# - cachecontrol=0.12.5
# - cairo=1.16.0
# - certifi=2019.11.28
# - cffi=1.13.2
# - chardet=3.0.4
# - click=7.0
# - cryptography=2.8
# - curl=7.68.0
# - cutadapt=2.8
# - cycler=0.10.0
# - cython=0.29.15
# - dbus=1.13.6
# - deblur=1.1.0
# - decorator=4.4.1
# - defusedxml=0.6.0
# - dendropy=4.4.0
# - dnaio=0.4.1
# - emperor=1.0.0
# - entrypoints=0.3
# - expat=2.2.9
# - fastcluster=1.1.26
# - fasttree=2.1.10
# - fontconfig=2.13.1
# - freetype=2.10.0
# - future=0.18.2
# - gcc_impl_linux-64=7.3.0
# - gcc_linux-64=7.3.0
# - gettext=0.19.8.1
# - gfortran_impl_linux-64=7.3.0
# - gfortran_linux-64=7.3.0
# - giflib=5.2.1
# - glib=2.58.3
# - gmp=6.2.0
# - gneiss=0.4.6
# - gnutls=3.6.5
# - graphite2=1.3.13
# - gsl=2.5
# - gst-plugins-base=1.14.5
# - gstreamer=1.14.5
# - gxx_impl_linux-64=7.3.0
# - gxx_linux-64=7.3.0
# - h5py=2.10.0
# - harfbuzz=2.4.0
# - hdf5=1.10.5
# - hdmedians=0.13
# - hmmer=3.1b2
# - icu=58.2
# - idna=2.9
# - ijson=2.6.1
# - importlib_metadata=1.5.0
# - ipykernel=5.1.4
# - ipython=7.12.0
# - ipython_genutils=0.2.0
# - ipywidgets=7.5.1
# - iqtree=1.6.12
# - jedi=0.16.0
# - jinja2=2.11.1
# - joblib=0.14.1
# - jpeg=9c
# - jsonschema=3.2.0
# - jupyter_client=6.0.0
# - jupyter_core=4.6.3
# - kiwisolver=1.1.0
# - krb5=1.16.4
# - lcms2=2.9
# - ld_impl_linux-64=2.33.1
# - libarbdb=6.0.6
# - libblas=3.8.0
# - libcblas=3.8.0
# - libcurl=7.68.0
# - libedit=3.1.20170329
# - libffi=3.2.1
# - libgcc=7.2.0
# - libgcc-ng=9.2.0
# - libgfortran-ng=7.3.0
# - libgomp=9.2.0
# - libiconv=1.15
# - liblapack=3.8.0
# - liblapacke=3.8.0
# - libopenblas=0.3.7
# - libpng=1.6.37
# - libsodium=1.0.17
# - libssh2=1.8.2
# - libstdcxx-ng=9.2.0
# - libtiff=4.1.0
# - libuuid=2.32.1
# - libxcb=1.13
# - libxml2=2.9.9
# - lockfile=0.12.2
# - lz4-c=1.8.3
# - mafft=7.310
# - make=4.3
# - markupsafe=1.1.1
# - matplotlib=3.1.1
# - matplotlib-base=3.1.1
# - mistune=0.8.4
# - more-itertools=8.2.0
# - msgpack-python=1.0.0
# - natsort=7.0.1
# - nbconvert=5.6.1
# - nbformat=5.0.4
# - ncurses=6.1
# - nettle=3.4.1
# - networkx=2.4
# - nose=1.3.7
# - notebook=6.0.3
# - numpy=1.18.1
# - olefile=0.46
# - openjdk=11.0.1
# - openssl=1.1.1d
# - packaging=20.1
# - pandas=0.25.3
# - pandoc=2.9.2
# - pandocfilters=1.4.2
# - pango=1.40.14
# - parso=0.6.1
# - patsy=0.5.1
# - pcre=8.44
# - perl=5.26.2
# - perl-archive-tar=2.32
# - perl-carp=1.38
# - perl-common-sense=3.74
# - perl-compress-raw-bzip2=2.087
# - perl-compress-raw-zlib=2.087
# - perl-exporter=5.72
# - perl-exporter-tiny=1.002001
# - perl-extutils-makemaker=7.36
# - perl-io-compress=2.087
# - perl-io-zlib=1.10
# - perl-json=4.02
# - perl-json-xs=2.34
# - perl-list-moreutils=0.428
# - perl-list-moreutils-xs=0.428
# - perl-pathtools=3.75
# - perl-scalar-list-utils=1.52
# - perl-types-serialiser=1.0
# - perl-xsloader=0.24
# - pexpect=4.8.0
# - pickleshare=0.7.5
# - pigz=2.3.4
# - pillow=7.0.0
# - pip=20.0.2
# - pixman=0.38.0
# - pluggy=0.12.0
# - prometheus_client=0.7.1
# - prompt_toolkit=3.0.3
# - psutil=5.7.0
# - pthread-stubs=0.4
# - ptyprocess=0.6.0
# - py=1.8.1
# - pycparser=2.19
# - pygments=2.5.2
# - pyopenssl=19.1.0
# - pyparsing=2.4.6
# - pyqt=5.9.2
# - pyrsistent=0.15.7
# - pysocks=1.7.1
# - pytest=5.3.5
# - python=3.6.7
# - python-dateutil=2.8.1
# - pytz=2019.3
# - pyyaml=5.3
# - pyzmq=19.0.0
# - q2-alignment=2020.2.0
# - q2-composition=2020.2.0
# - q2-cutadapt=2020.2.0
# - q2-dada2=2020.2.0
# - q2-deblur=2020.2.0
# - q2-demux=2020.2.0
# - q2-diversity=2020.2.0
# - q2-emperor=2020.2.0
# - q2-feature-classifier=2020.2.0
# - q2-feature-table=2020.2.0
# - q2-fragment-insertion=2020.2.0
# - q2-gneiss=2020.2.0
# - q2-longitudinal=2020.2.0
# - q2-metadata=2020.2.0
# - q2-phylogeny=2020.2.0
# - q2-quality-control=2020.2.0
# - q2-quality-filter=2020.2.0
# - q2-sample-classifier=2020.2.0
# - q2-taxa=2020.2.0
# - q2-types=2020.2.0
# - q2-vsearch=2020.2.0
# - q2cli=2020.2.0
# - q2templates=2020.2.0
# - qiime2=2020.2.0
# - qt=5.9.7
# - r-assertthat=0.2.1
# - r-backports=1.1.5
# - r-base=3.5.1
# - r-bh=1.72.0_3
# - r-bitops=1.0_6
# - r-cli=2.0.2
# - r-cluster=2.1.0
# - r-colorspace=1.4_1
# - r-crayon=1.3.4
# - r-data.table=1.12.6
# - r-digest=0.6.25
# - r-ellipsis=0.3.0
# - r-fansi=0.4.1
# - r-farver=2.0.3
# - r-formatr=1.7
# - r-futile.logger=1.4.3
# - r-futile.options=1.0.1
# - r-ggplot2=3.2.1
# - r-glue=1.3.1
# - r-gtable=0.3.0
# - r-hwriter=1.3.2
# - r-labeling=0.3
# - r-lambda.r=1.2.4
# - r-lattice=0.20_40
# - r-latticeextra=0.6_28
# - r-lazyeval=0.2.2
# - r-lifecycle=0.1.0
# - r-magrittr=1.5
# - r-mass=7.3_51.5
# - r-matrix=1.2_18
# - r-matrixstats=0.55.0
# - r-mgcv=1.8_31
# - r-munsell=0.5.0
# - r-nlme=3.1_144
# - r-permute=0.9_5
# - r-pillar=1.4.3
# - r-pkgconfig=2.0.3
# - r-plyr=1.8.5
# - r-r6=2.4.1
# - r-rcolorbrewer=1.1_2
# - r-rcpp=1.0.3
# - r-rcppparallel=4.4.4
# - r-rcurl=1.98_1.1
# - r-reshape2=1.4.3
# - r-rlang=0.4.4
# - r-scales=1.1.0
# - r-snow=0.4_3
# - r-stringi=1.4.3
# - r-stringr=1.4.0
# - r-tibble=2.1.3
# - r-utf8=1.1.4
# - r-vctrs=0.2.3
# - r-vegan=2.5_6
# - r-viridislite=0.3.0
# - r-withr=2.1.2
# - r-zeallot=0.1.0
# - raxml=8.2.12
# - readline=8.0
# - requests=2.23.0
# - scikit-bio=0.5.5
# - scikit-learn=0.22.1
# - scipy=1.4.1
# - seaborn=0.10.0
# - send2trash=1.5.0
# - sepp=4.3.10
# - setuptools=45.2.0
# - sina=1.6.0
# - sip=4.19.8
# - six=1.14.0
# - sortmerna=2.0
# - sqlite=3.30.1
# - statsmodels=0.11.1
# - tbb=2019.9
# - terminado=0.8.3
# - testpath=0.4.4
# - tk=8.6.10
# - tktable=2.10
# - tornado=6.0.3
# - traitlets=4.3.3
# - tzlocal=2.0.0
# - unifrac=0.10.0
# - urllib3=1.25.7
# - vsearch=2.7.0
# - wcwidth=0.1.8
# - webencodings=0.5.1
# - wheel=0.34.2
# - widgetsnbextension=3.5.1
# - xopen=0.8.4
# - xorg-fixesproto=5.0
# - xorg-inputproto=2.3.2
# - xorg-kbproto=1.0.7
# - xorg-libice=1.0.10
# - xorg-libsm=1.2.3
# - xorg-libx11=1.6.9
# - xorg-libxau=1.0.9
# - xorg-libxdmcp=1.1.3
# - xorg-libxext=1.3.4
# - xorg-libxfixes=5.0.3
# - xorg-libxi=1.7.10
# - xorg-libxrender=0.9.10
# - xorg-libxtst=1.2.3
# - xorg-recordproto=1.14.2
# - xorg-renderproto=0.11.1
# - xorg-xextproto=7.3.0
# - xorg-xproto=7.0.31
# - xz=5.2.4
# - yaml=0.2.2
# - zeromq=4.3.2
# - zipp=3.0.0
# - zlib=1.2.11
# - zstd=1.4.4
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/traitar.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - scipy
# - pandas
# - numpy
# - matplotlib
# - pigz
# - bioconda::hmmer
# - pip:
#   - traitar3>=0.1.1
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/cctyper.yaml <==
# channels:
# - conda-forge
# - bioconda
# - russel88
# dependencies:
# - pigz
# - cctyper
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/comparem.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::comparem
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/bigscape.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - python=3.6
# - hmmer
# - biopython
# - fasttree
# - numpy
# - scipy
# - networkx
# - scikit-learn=0.19.1
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/rgi.yaml <==
# name: rgi
# channels:
#   - bioconda
#   - conda-forge
#   - defaults
# dependencies:
#   - _libgcc_mutex=0.1=conda_forge
#   - _openmp_mutex=4.5=1_llvm
#   - bamtools=2.5.1=he860b03_5
#   - bedtools=2.29.2=hc088bd4_0
#   - biopython=1.72=py36h14c3975_1000
#   - blast=2.9.0=pl526h3066fca_4
#   - bowtie2=2.4.1=py36h7f0b59b_2
#   - bwa=0.7.17=hed695b0_7
#   - bzip2=1.0.8=h516909a_2
#   - ca-certificates=2020.4.5.2=hecda079_0
#   - certifi=2020.4.5.2=py36h9f0ad1d_0
#   - curl=7.69.1=h33f0ec9_0
#   - cycler=0.10.0=py_2
#   - diamond=0.8.36=h8b12597_4
#   - entrez-direct=13.3=pl526h375a9b1_0
#   - expat=2.2.9=he1b5a44_2
#   - filetype=1.0.7=pyh9f0ad1d_0
#   - freetype=2.10.2=he06d7ca_0
#   - icu=64.2=he1b5a44_1
#   - kiwisolver=1.2.0=py36hdb11119_0
#   - krb5=1.17.1=h2fd8d38_0
#   - ld_impl_linux-64=2.34=h53a641e_5
#   - libblas=3.8.0=16_openblas
#   - libcblas=3.8.0=16_openblas
#   - libcurl=7.69.1=hf7181ac_0
#   - libdeflate=1.0=h14c3975_1
#   - libedit=3.1.20191231=h46ee950_0
#   - libffi=3.2.1=he1b5a44_1007
#   - libgcc-ng=9.2.0=h24d8f2e_2
#   - libgfortran-ng=7.5.0
#   - liblapack=3.8.0=16_openblas
#   - libopenblas=0.3.9=h5ec1e0e_0
#   - libpng=1.6.37=hed695b0_1
#   - libssh2=1.9.0=hab1572f_2
#   - libstdcxx-ng=9.2.0=hdf63c60_2
#   - llvm-openmp=10.0.0=hc9558a2_0
#   - matplotlib-base=3.2.1=py36hb8e4980_0
#   - ncurses=6.1=hf484d3e_1002
#   - numpy=1.18.5=py36h7314795_0
#   - oligoarrayaux=3.8=hc9558a2_0
#   - openssl=1.1.1g=h516909a_0
#   - pandas=1.0.4=py36h830a2c2_0
#   - patsy=0.5.1=py_0
#   - pcre=8.44=he1b5a44_0
#   - perl=5.26.2=h516909a_1006
#   - perl-app-cpanminus=1.7044=pl526_1
#   - perl-archive-tar=2.32=pl526_0
#   - perl-base=2.23=pl526_1
#   - perl-business-isbn=3.004=pl526_0
#   - perl-business-isbn-data=20140910.003=pl526_0
#   - perl-carp=1.38=pl526_3
#   - perl-common-sense=3.74=pl526_2
#   - perl-compress-raw-bzip2=2.087=pl526he1b5a44_0
#   - perl-compress-raw-zlib=2.087=pl526hc9558a2_0
#   - perl-constant=1.33=pl526_1
#   - perl-data-dumper=2.173=pl526_0
#   - perl-digest-hmac=1.03=pl526_3
#   - perl-digest-md5=2.55=pl526_0
#   - perl-encode=2.88=pl526_1
#   - perl-encode-locale=1.05=pl526_6
#   - perl-exporter=5.72=pl526_1
#   - perl-exporter-tiny=1.002001=pl526_0
#   - perl-extutils-makemaker=7.36=pl526_1
#   - perl-file-listing=6.04=pl526_1
#   - perl-file-path=2.16=pl526_0
#   - perl-file-temp=0.2304=pl526_2
#   - perl-html-parser=3.72=pl526h6bb024c_5
#   - perl-html-tagset=3.20=pl526_3
#   - perl-html-tree=5.07=pl526_1
#   - perl-http-cookies=6.04=pl526_0
#   - perl-http-daemon=6.01=pl526_1
#   - perl-http-date=6.02=pl526_3
#   - perl-http-message=6.18=pl526_0
#   - perl-http-negotiate=6.01=pl526_3
#   - perl-io-compress=2.087=pl526he1b5a44_0
#   - perl-io-html=1.001=pl526_2
#   - perl-io-socket-ssl=2.066=pl526_0
#   - perl-io-zlib=1.10=pl526_2
#   - perl-json=4.02=pl526_0
#   - perl-json-xs=2.34=pl526h6bb024c_3
#   - perl-libwww-perl=6.39=pl526_0
#   - perl-list-moreutils=0.428=pl526_1
#   - perl-list-moreutils-xs=0.428=pl526_0
#   - perl-lwp-mediatypes=6.04=pl526_0
#   - perl-lwp-protocol-https=6.07=pl526_4
#   - perl-mime-base64=3.15=pl526_1
#   - perl-mozilla-ca=20180117=pl526_1
#   - perl-net-http=6.19=pl526_0
#   - perl-net-ssleay=1.88=pl526h90d6eec_0
#   - perl-ntlm=1.09=pl526_4
#   - perl-parent=0.236=pl526_1
#   - perl-pathtools=3.75=pl526h14c3975_1
#   - perl-scalar-list-utils=1.52=pl526h516909a_0
#   - perl-socket=2.027=pl526_1
#   - perl-storable=3.15=pl526h14c3975_0
#   - perl-test-requiresinternet=0.05=pl526_0
#   - perl-time-local=1.28=pl526_1
#   - perl-try-tiny=0.30=pl526_1
#   - perl-types-serialiser=1.0=pl526_2
#   - perl-uri=1.76=pl526_0
#   - perl-www-robotrules=6.02=pl526_3
#   - perl-xml-namespacesupport=1.12=pl526_0
#   - perl-xml-parser=2.44=pl526h4e0c4b3_7
#   - perl-xml-sax=1.02=pl526_0
#   - perl-xml-sax-base=1.09=pl526_0
#   - perl-xml-sax-expat=0.51=pl526_3
#   - perl-xml-simple=2.25=pl526_1
#   - perl-xsloader=0.24=pl526_0
#   - pip=20.1.1=py_1
#   - prodigal=2.6.3=h516909a_2
#   - pyahocorasick=1.4.0=py36h8c4c3a4_1
#   - pyfaidx=0.5.8=py_1
#   - pyparsing=2.4.7=pyh9f0ad1d_0
#   - python=3.6.10=h8356626_1011_cpython
#   - python-dateutil=2.8.1=py_0
#   - python_abi=3.6=1_cp36m
#   - pytz=2020.1=pyh9f0ad1d_0
#   - readline=8.0=hf8c457e_0
#   - rgi=5.1.0=py_1
#   - samtools=1.9=h8571acd_11
#   - scipy=1.4.1=py36h2d22cac_3
#   - seaborn=0.10.1=py_0
#   - setuptools=47.1.1=py36h9f0ad1d_0
#   - six=1.15.0=pyh9f0ad1d_0
#   - sqlite=3.30.1=hcee41ef_0
#   - statsmodels=0.11.1=py36h8c4c3a4_1
#   - tbb=2020.1=hc9558a2_0
#   - tk=8.6.10=hed695b0_0
#   - tornado=6.0.4=py36h8c4c3a4_1
#   - wheel=0.34.2=py_1
#   - xz=5.2.5=h516909a_0
#   - zlib=1.2.11=h516909a_1006
# prefix: /home/users/ldenies/apps/miniconda3/envs/rgi
#
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/pathofact_hmm.yaml <==
# channels:
#   - bioconda
#   - conda-forge
#   - defaults
# dependencies:
#   - _libgcc_mutex=0.1=conda_forge
#   - _openmp_mutex=4.5=0_gnu
#   - hmmer=3.2.1=he1b5a44_2
#   - libgcc-ng=9.2.0=h24d8f2e_2
#   - libgomp=9.2.0=h24d8f2e_2
#   - libstdcxx-ng=9.2.0=hdf63c60_2
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/pathofact_biopython.yaml <==
# channels:
#   - conda-forge
#   - bioconda
#   - defaults
# dependencies:
#   - _libgcc_mutex=0.1=main
#   - biopython=1.74=py36h516909a_0
#   - ca-certificates=2019.6.16=hecc5488_0
#   - certifi=2019.6.16=py36_1
#   - cycler=0.10.0=py_1
#   - dbus=1.13.6=he372182_0
#   - expat=2.2.5=he1b5a44_1003
#   - fontconfig=2.13.1=he4413a7_1000
#   - freetype=2.10.0=he983fc9_0
#   - gettext=0.19.8.1=hc5be6a0_1002
#   - glib=2.58.3=h6f030ca_1002
#   - gst-plugins-base=1.14.5=h0935bb2_0
#   - gstreamer=1.14.5=h36ae1b5_0
#   - icu=58.2=hf484d3e_1000
#   - joblib=0.13.2=py_0
#   - jpeg=9c=h14c3975_1001
#   - kiwisolver=1.1.0=py36hc9558a2_0
#   - libblas=3.8.0=11_openblas
#   - libcblas=3.8.0=11_openblas
#   - libedit=3.1.20181209=hc058e9b_0
#   - libffi=3.2.1=hd88cf55_4
#   - libgcc-ng=9.1.0=hdf63c60_0
#   - libgfortran-ng=7.3.0=hdf63c60_0
#   - libiconv=1.15=h516909a_1005
#   - liblapack=3.8.0=11_openblas
#   - libopenblas=0.3.6=h6e990d7_6
#   - libpng=1.6.37=hed695b0_0
#   - libstdcxx-ng=9.1.0=hdf63c60_0
#   - libuuid=2.32.1=h14c3975_1000
#   - libxcb=1.13=h14c3975_1002
#   - libxml2=2.9.9=h13577e0_2
#   - matplotlib=3.1.0=py36h5429711_0
#   - ncurses=6.1=he6710b0_1
#   - numpy=1.17.0=py36h95a1406_0
#   - openssl=1.1.1c=h516909a_0
#   - pandas=0.25.0=py36hb3f55d8_0
#   - patsy=0.5.1=py_0
#   - pcre=8.41=hf484d3e_1003
#   - pip=19.1.1=py36_0
#   - pthread-stubs=0.4=h14c3975_1001
#   - pyparsing=2.4.2=py_0
#   - pyqt=5.9.2=py36hcca6a23_2
#   - python=3.6.9=h265db76_0
#   - python-dateutil=2.8.0=py_0
#   - pytz=2019.2=py_0
#   - qt=5.9.7=h52cfd70_2
#   - readline=7.0=h7b6447c_5
#   - scikit-learn=0.21.3=py36hcdab131_0
#   - scipy=1.3.0=py36h921218d_1
#   - seaborn=0.9.0=py_0
#   - setuptools=41.0.1=py36_0
#   - sip=4.19.8=py36hf484d3e_1000
#   - six=1.12.0=py36_1000
#   - sqlite=3.29.0=h7b6447c_0
#   - statsmodels=0.10.1=py36hc1659b7_0
#   - tk=8.6.8=hbc83047_0
#   - tornado=6.0.3=py36h516909a_0
#   - wheel=0.33.4=py36_0
#   - xorg-libxau=1.0.9=h14c3975_0
#   - xorg-libxdmcp=1.1.3=h516909a_0
#   - xz=5.2.4=h14c3975_4
#   - zlib=1.2.11=h7b6447c_3
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/platon.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - pigz
# - bioconda::platon
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llg//bin/envs/plasflow.yaml <==
# channels:
#   # for PlasFlow
#   - smaegol
#   # rest
#   - bioconda
#   - conda-forge
#   - defaults
# dependencies:
#   - seqkit
#   - _libgcc_mutex=0.1=conda_forge
#   - _openmp_mutex=4.5=1_llvm
#   - _r-mutex=1.0.1=anacondar_1
#   - backports=1.0=py_2
#   - backports.weakref=1.0rc1=py35_1
#   - bioconductor-biocgenerics=0.22.0=r3.3.2_0
#   - bioconductor-biostrings=2.42.1=r3.3.2_0
#   - bioconductor-iranges=2.8.2=r3.3.2_0
#   - bioconductor-s4vectors=0.12.2=r3.3.2_0
#   - bioconductor-xvector=0.14.1=r3.3.2_0
#   - bioconductor-zlibbioc=1.20.0=r3.3.2_1
#   - biopython=1.68=py35_0
#   - blas=2.16=openblas
#   - bleach=1.5.0=py35_0
#   - bzip2=1.0.8=h516909a_2
#   - ca-certificates=2020.4.5.1=hecc5488_0
#   - cairo=1.14.6=4
#   - certifi=2018.8.24=py35_1001
#   - curl=7.52.1=0
#   - fontconfig=2.12.1=6
#   - freetype=2.7=1
#   - gettext=0.19.8.1=hc5be6a0_1002
#   - glib=2.51.4=0
#   - graphite2=1.3.13=he1b5a44_1001
#   - gsl=2.6=h294904e_0
#   - harfbuzz=1.4.3=0
#   - html5lib=0.9999999=py35_0
#   - icu=58.2=hf484d3e_1000
#   - jpeg=9c=h14c3975_1001
#   - libblas=3.8.0=16_openblas
#   - libcblas=3.8.0=16_openblas
#   - libffi=3.2.1=he1b5a44_1007
#   - libgcc=7.2.0=h69d50b8_2
#   - libgcc-ng=9.2.0=h24d8f2e_2
#   - libgfortran-ng=7.3.0=hdf63c60_5
#   - libiconv=1.15=h516909a_1006
#   - liblapack=3.8.0=16_openblas
#   - liblapacke=3.8.0=16_openblas
#   - libopenblas=0.3.9=h5ec1e0e_0
#   - libpng=1.6.28=1
#   - libstdcxx-ng=9.2.0=hdf63c60_2
#   - libtiff=4.0.7=0
#   - libxml2=2.9.5=0
#   - llvm-openmp=10.0.0=hc9558a2_0
#   - markdown=3.2.1=py_0
#   - mmtf-python=1.0.2=py35_0
#   - mock=2.0.0=py35_0
#   - msgpack-python=0.5.6=py35h2d50403_3
#   - ncurses=5.9=10
#   - numpy=1.15.2=py35h99e49ec_0
#   - numpy-base=1.15.2=py35h2f8d375_0
#   - olefile=0.46=py_0
#   - openssl=1.0.2u=h516909a_0
#   - pandas=0.23.4=py35hf8a1672_0
#   - pango=1.40.4=0
#   - pbr=5.4.2=py_0
#   - pcre=8.44=he1b5a44_0
#   - pillow=4.3.0=py35_0
#   - pip=20.0.2=py_2
#   - pixman=0.34.0=h14c3975_1003
#   - protobuf=3.4.0=py35_0
#   - python=3.5.4=0
#   - python-dateutil=2.8.1=py_0
#   - pytz=2019.3=py_0
#   - r-base=3.3.2=5
#   - readline=6.2=0
#   - reportlab=3.4.0=py35_0
#   - rpy2=2.7.8=py35r3.3.2_1
#   - scikit-learn=0.20.0=py35h22eb022_1
#   - scipy=1.1.0=py35he2b7bc3_1
#   - setuptools=40.4.3=py35_0
#   - six=1.14.0=py_1
#   - sqlite=3.13.0=1
#   - tensorflow=1.3.0=py35_0
#   - tk=8.5.19=2
#   - webencodings=0.5.1=py_1
#   - werkzeug=1.0.1=pyh9f0ad1d_0
#   - wheel=0.34.2=py_1
#   - xz=5.2.5=h516909a_0
#   - zlib=1.2.8=3
#   # PlasFlow: should be installed from smaegol, NOT from pip
#   - plasflow=1.1.0

# %%
pipelineInfo('/ebio/abt3_projects/software/dev/ll_pipelines/llprimer/')
# Out:
# LLPRIMER
# ========
#
# Ley Lab Primer generation pipeline (LLPRIMER)
#
# * Version: 0.3.0
# * Authors:
#   * Nick Youngblut <nyoungb2@gmail.com>
# * Maintainers:
#   * Nick Youngblut <nyoungb2@gmail.com>
#
# --- conda envs ---
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/pdp.yaml <==
# channels:
# - conda-forge
# - bioconda
# dependencies:
# - python=3.7
# - intervaltree
# - prodigal
# - blast
# - bedtools
# - mafft
# - mummer=3.23
# - emboss
# - primer3=1.1.4
# - biopython<1.78
# - pybedtools
# - joblib
# - tqdm
# - openpyxl
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/genes.yaml <==
# channels:
# - bioconda
# dependencies:
# - pigz
# - python=3
# - numpy
# - pyfaidx
# - bioconda::seqkit
# - bioconda::fasta-splitter
# - bioconda::vsearch
# - bioconda::mmseqs2
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/aln.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::revtrans
# - bioconda::kalign3
# - bioconda::mafft
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/blast.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::seqkit
# - bioconda::biopython<1.78
# - bioconda::blast>=2.10.1
#
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/primer3.yaml <==
# channels:
# - bioconda
# - conda-forge
# dependencies:
# - pigz
# - bioconda::biopython<1.78
# - bioconda::primer3-py
# ==> /ebio/abt3_projects/software/dev/ll_pipelines/llprimer//bin/envs/prokka.yaml <==
# channels:
# - bioconda
# dependencies:
# - pigz
# - bioconda::prokka

# %%
sessionInfo()
# Out:
# R version 3.6.3 (2020-02-29)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Georg_animal_feces/envs/tidyverse/lib/libopenblasp-r0.3.9.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.6 ggplot2_3.3.1     tidyr_1.1.0       dplyr_1.0.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.4.6     magrittr_1.5     munsell_0.5.0    tidyselect_1.1.0
#  [5] uuid_0.1-4       colorspace_1.4-1 R6_2.4.1         rlang_0.4.6
#  [9] tools_3.6.3      grid_3.6.3       gtable_0.3.0     withr_2.2.0
# [13] htmltools_0.4.0  ellipsis_0.3.1   digest_0.6.25    tibble_3.0.1
# [17] lifecycle_0.2.0  crayon_1.3.4     IRdisplay_0.7.0  purrr_0.3.4
# [21] repr_1.1.0       base64enc_0.1-3  vctrs_0.3.1      IRkernel_1.1
# [25] glue_1.4.1       evaluate_0.14    stringi_1.4.6    pbdZMQ_0.3-3
# [29] compiler_3.6.3   pillar_1.4.4     scales_1.1.1     generics_0.0.2
# [33] jsonlite_1.6.1   pkgconfig_2.0.3
